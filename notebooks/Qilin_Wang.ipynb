# %% [markdown]
# ## Q1.1

# %%
from ift6758.data import get_player_stats
import pandas as pd
import numpy as np
import os

# %%
os.path.basename("/data/2020")
# Out:
# '2020'

# %%
df = get_player_stats(2016, 'goalies')
# Out:
# Retrieving data from 'https://www.hockey-reference.com/leagues/NHL_2016_goalies.html'...

# %%
# df.sort_values(by=['SV%'], ascending=False)

# %% [markdown]
# ## Q1.2
#
# I propose using `log(1+shot against)`, i.e. `log(1+SA)` as a scaling factor, where the `1` is to deal with the goalies who have zero appearances. So the proposed estimator is `SV / SA * log(1+SA)`

# %%
## Q1.2

# %%
print(np.log(1+5))
print(np.log(1+500))
# Out:
# 1.791759469228055
# 6.2166061010848646

# %%
np.log(1+10)
# Out:
# 2.3978952727983707

# %%
import requests
r = requests.get("https://statsapi.web.nhl.com/api/v1/game/2017020001/feed/live/")

# %%
custom_dict = r.json()
custom_dict['gameData']['game']
# Out:
# {'pk': 2017020001, 'season': '20172018', 'type': 'R'}

# %%
def get_data(year_start, year_end):
    download_root = "https://statsapi.web.nhl.com/api/v1/game/"

    download_end = "/feed/live/"
    for i in range(year_end - year_start):
        year = str(year_start + i)
        for j in range(1):
            if j == 0:
                season = "02"
                if int(year) < 2017:
                    games_limit = 1230
                else:
                    games_limit = 1271
                for k in range(games_limit):
                    game_number = str(k+1).zfill(4)
                    game_id_str = year + season + game_number
                    # print(game_id_str)
            else:
                season = "03"
                for k in range(4):
                    round = k + 1
                    for l in range(8):
                        matchup = l + 1
                        for m in range(7):
                            game = m + 1
                            print(str(k+i+l))
                            game_number = str(k+i+l).zfill(4)
                            game_id_str = year + season + game_number
                            print(game_id_str)

    # r = requests.get(download_root +")
    print(download_root + game_id_str + download_end)


get_data(2016,2017)
# Out:
# https://statsapi.web.nhl.com/api/v1/game/2016021230/feed/live/

# %%
print(zip(range(4),range(4)))
# Out:
# <zip object at 0x000001173D3BBDC0>

# %%
print([i+1 for i in range(4)])
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# # Data Acquisition

# %%
from ift6758.data.functions import loadstats
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import ipywidgets as widgets
from IPython.display import display
import plotly.express as px
import pandas as pd
import json

# %%
#preload and download from web if not acquired (set to false to download all data)
downloaded = True
if not downloaded:
    datayear = 2016
    while datayear <= 2020:
        loadstats(datayear,'./data/')
        datayear += 1
# Out:
# Error code: 404 at gameID:2016021231. Game not found.
# size of data in regular season: 1230
# Error code: 404 at gameID:2016030147. Game not found.
# Error code: 404 at gameID:2016030176. Game not found.
# size of data in regular season & playoffs: 1332
# size of data in regular season: 1271
# size of data in regular season & playoffs: 1376
# size of data in regular season: 1271
# size of data in regular season & playoffs: 1376
# size of data in regular season: 1271
# Error code: 404 at gameID:2019030007. Game not found.
# Error code: 404 at gameID:2019030017. Game not found.
# Error code: 404 at gameID:2019030026. Game not found.
# Error code: 404 at gameID:2019030036. Game not found.
# Error code: 404 at gameID:2019030046. Game not found.
# Error code: 404 at gameID:2019030056. Game not found.
# Error code: 404 at gameID:2019030066. Game not found.
# Error code: 404 at gameID:2019030076. Game not found.
# Error code: 404 at gameID:2019030086. Game not found.
# Error code: 404 at gameID:2019030096. Game not found.
# size of data in regular season & playoffs: 1428
# Error code: 404 at gameID:2020020869. Game not found.
# size of data in regular season: 868
# size of data in regular season & playoffs: 973

# %%
dfs = loadstats(2019,'./data/')
# print(df2019.iloc[:,1270])
# print(df2019['2019020001'])

# %%
df_2020 = loadstats(2020, './data/')
# Out:
# Error code: 404 at gameID:2020020869. Game not found.
# size of data in regular season: 868
# size of data in regular season & playoffs: 973

# %%
import os
dfs_2018 = []
for file in os.path('./data/2020/'):
    with open(file) as f:
        json_data = pd.json_normalize(json.loads(f.read()))
    dfs_2018.append(json_data)
df_2018 = pd.concat(dfs, sort=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23924/1789066695.py in <module>
#       1 import os
#       2 dfs_2018 = []
# ----> 3 for file in os.path('./data/2020/'):
#       4     with open(file) as f:
#       5         json_data = pd.json_normalize(json.loads(f.read()))
#
# TypeError: 'module' object is not callable

# %%
dfs.shape
# Out:
# (6, 1428)

# %%
dfs
# Out:
#                                                   2019020001  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019020001
# link                       /api/v1/game/2019020001/feed/live
# metaData   {'wait': 10, 'timeStamp': '20191106_204348', '...
# gameData   {'game': {'pk': 2019020001, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019020002  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019020002
# link                       /api/v1/game/2019020002/feed/live
# metaData        {'wait': 10, 'timeStamp': '20191106_204355'}
# gameData   {'game': {'pk': 2019020002, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019020003  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019020003
# link                       /api/v1/game/2019020003/feed/live
# metaData        {'wait': 10, 'timeStamp': '20191106_204404'}
# gameData   {'game': {'pk': 2019020003, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019020004  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019020004
# link                       /api/v1/game/2019020004/feed/live
# metaData        {'wait': 10, 'timeStamp': '20191106_204412'}
# gameData   {'game': {'pk': 2019020004, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019020005  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019020005
# link                       /api/v1/game/2019020005/feed/live
# metaData        {'wait': 10, 'timeStamp': '20191106_204420'}
# gameData   {'game': {'pk': 2019020005, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019020006  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019020006
# link                       /api/v1/game/2019020006/feed/live
# metaData        {'wait': 10, 'timeStamp': '20191106_204429'}
# gameData   {'game': {'pk': 2019020006, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019020007  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019020007
# link                       /api/v1/game/2019020007/feed/live
# metaData        {'wait': 10, 'timeStamp': '20191106_204438'}
# gameData   {'game': {'pk': 2019020007, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019020008  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019020008
# link                       /api/v1/game/2019020008/feed/live
# metaData        {'wait': 10, 'timeStamp': '20191106_204446'}
# gameData   {'game': {'pk': 2019020008, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019020009  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019020009
# link                       /api/v1/game/2019020009/feed/live
# metaData        {'wait': 10, 'timeStamp': '20191106_204455'}
# gameData   {'game': {'pk': 2019020009, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019020010  ...  \
# copyright  NHL and the NHL Shield are registered trademar...  ...
# gamePk                                            2019020010  ...
# link                       /api/v1/game/2019020010/feed/live  ...
# metaData        {'wait': 10, 'timeStamp': '20191106_204502'}  ...
# gameData   {'game': {'pk': 2019020010, 'season': '2019202...  ...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...  ...
#
#                                                   2019030325  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019030325
# link                       /api/v1/game/2019030325/feed/live
# metaData        {'wait': 10, 'timeStamp': '20200915_145520'}
# gameData   {'game': {'pk': 2019030325, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019030326  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019030326
# link                       /api/v1/game/2019030326/feed/live
# metaData        {'wait': 10, 'timeStamp': '20200915_030341'}
# gameData   {'game': {'pk': 2019030326, 'season': '2019202...
# liveData   {'plays': {'allPlays': [], 'scoringPlays': [],...
#
#                                                   2019030327  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019030327
# link                       /api/v1/game/2019030327/feed/live
# metaData        {'wait': 10, 'timeStamp': '20200915_030342'}
# gameData   {'game': {'pk': 2019030327, 'season': '2019202...
# liveData   {'plays': {'allPlays': [], 'scoringPlays': [],...
#
#                                                   2019030411  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019030411
# link                       /api/v1/game/2019030411/feed/live
# metaData        {'wait': 10, 'timeStamp': '20200921_213742'}
# gameData   {'game': {'pk': 2019030411, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019030412  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019030412
# link                       /api/v1/game/2019030412/feed/live
# metaData        {'wait': 10, 'timeStamp': '20200922_040018'}
# gameData   {'game': {'pk': 2019030412, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019030413  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019030413
# link                       /api/v1/game/2019030413/feed/live
# metaData        {'wait': 10, 'timeStamp': '20200924_053615'}
# gameData   {'game': {'pk': 2019030413, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019030414  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019030414
# link                       /api/v1/game/2019030414/feed/live
# metaData        {'wait': 10, 'timeStamp': '20201012_000003'}
# gameData   {'game': {'pk': 2019030414, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019030415  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019030415
# link                       /api/v1/game/2019030415/feed/live
# metaData        {'wait': 10, 'timeStamp': '20200927_185956'}
# gameData   {'game': {'pk': 2019030415, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019030416  \
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019030416
# link                       /api/v1/game/2019030416/feed/live
# metaData        {'wait': 10, 'timeStamp': '20200929_092143'}
# gameData   {'game': {'pk': 2019030416, 'season': '2019202...
# liveData   {'plays': {'allPlays': [{'result': {'event': '...
#
#                                                   2019030417
# copyright  NHL and the NHL Shield are registered trademar...
# gamePk                                            2019030417
# link                       /api/v1/game/2019030417/feed/live
# metaData        {'wait': 10, 'timeStamp': '20200922_000343'}
# gameData   {'game': {'pk': 2019030417, 'season': '2019202...
# liveData   {'plays': {'allPlays': [], 'scoringPlays': [],...
#
# [6 rows x 1428 columns]

# %%
import sys, importlib
importlib.reload(sys.modules['ift6758.data.tidyData'])
from ift6758.data.tidyData import tidyData

# %%
from ift6758.data.tidyData import tidyData, check_size_eq
# dfs = loadstats(2019,'./data/')
d1 = dfs
d1.shape
# Out:
# (6, 1428)

# %%
d2 = tidyData(d1)
# Out:
# emptyNet = True
#  i  302
#  game_id 2019020005
# 283 event idx
#
# emptyNet = True
#  i  381
#  game_id 2019020006
# 358 event idx
#
# emptyNet = True
#  i  591
#  game_id 2019020009
# 288 event idx
#
# emptyNet = True
#  i  703
#  game_id 2019020011
# 330 event idx
#
# emptyNet = True
#  i  1613
#  game_id 2019020025
# 310 event idx
#
# emptyNet = True
#  i  1676
#  game_id 2019020026
# 313 event idx
#
# emptyNet = True
#  i  1801
#  game_id 2019020028
# 313 event idx
#
# emptyNet = True
#  i  2326
#  game_id 2019020036
# 327 event idx
#
# emptyNet = True
#  i  2618
#  game_id 2019020041
# 302 event idx
#
# emptyNet = True
#  i  3076
#  game_id 2019020048
# 366 event idx
#
# emptyNet = True
#  i  3258
#  game_id 2019020051
# 343 event idx
#
# emptyNet = True
#  i  3392
#  game_id 2019020053
# 318 event idx
#
# emptyNet = True
#  i  3603
#  game_id 2019020056
# 308 event idx
#
# emptyNet = True
#  i  3859
#  game_id 2019020060
# 329 event idx
#
# emptyNet = True
#  i  3908
#  game_id 2019020061
# 308 event idx
#
# emptyNet = True
#  i  3962
#  game_id 2019020062
# 293 event idx
#
# emptyNet = True
#  i  4032
#  game_id 2019020063
# 317 event idx
#
# emptyNet = True
#  i  4160
#  game_id 2019020065
# 330 event idx
#
# emptyNet = True
#  i  4229
#  game_id 2019020066
# 303 event idx
#
# emptyNet = True
#  i  4479
#  game_id 2019020070
# 326 event idx
#
# emptyNet = True
#  i  4544
#  game_id 2019020071
# 291 event idx
#
# emptyNet = True
#  i  5040
#  game_id 2019020079
# 329 event idx
#
# emptyNet = True
#  i  5254
#  game_id 2019020083
# 327 event idx
#
# emptyNet = True
#  i  5318
#  game_id 2019020084
# 324 event idx
#
# emptyNet = True
#  i  5572
#  game_id 2019020088
# 288 event idx
#
# emptyNet = True
#  i  5759
#  game_id 2019020091
# 282 event idx
#
# emptyNet = True
#  i  6088
#  game_id 2019020096
# 294 event idx
#
# emptyNet = True
#  i  6148
#  game_id 2019020097
# 297 event idx
#
# emptyNet = True
#  i  6347
#  game_id 2019020100
# 289 event idx
#
# emptyNet = True
#  i  6486
#  game_id 2019020102
# 321 event idx
#
# emptyNet = True
#  i  6608
#  game_id 2019020104
# 290 event idx
#
# emptyNet = True
#  i  6921
#  game_id 2019020108
# 298 event idx
#
# emptyNet = True
#  i  6984
#  game_id 2019020109
# 298 event idx
#
# emptyNet = True
#  i  7272
#  game_id 2019020114
# 254 event idx
#
# emptyNet = True
#  i  7470
#  game_id 2019020117
# 281 event idx
#
# emptyNet = True
#  i  7524
#  game_id 2019020118
# 309 event idx
#
# emptyNet = True
#  i  7525
#  game_id 2019020118
# 315 event idx
#
# emptyNet = True
#  i  7658
#  game_id 2019020120
# 337 event idx
#
# emptyNet = True
#  i  8069
#  game_id 2019020126
# 340 event idx
#
# emptyNet = True
#  i  8600
#  game_id 2019020135
# 261 event idx
#
# emptyNet = True
#  i  8729
#  game_id 2019020137
# 290 event idx
#
# emptyNet = True
#  i  9045
#  game_id 2019020142
# 283 event idx
#
# emptyNet = True
#  i  9121
#  game_id 2019020143
# 339 event idx
#
# emptyNet = True
#  i  9314
#  game_id 2019020146
# 321 event idx
#
# emptyNet = True
#  i  9496
#  game_id 2019020149
# 278 event idx
#
# emptyNet = True
#  i  9876
#  game_id 2019020156
# 246 event idx
#
# emptyNet = True
#  i  9928
#  game_id 2019020157
# 271 event idx
#
# emptyNet = True
#  i  10233
#  game_id 2019020162
# 284 event idx
#
# emptyNet = True
#  i  10443
#  game_id 2019020165
# 312 event idx
#
# emptyNet = True
#  i  10497
#  game_id 2019020166
# 322 event idx
#
# emptyNet = True
#  i  10693
#  game_id 2019020169
# 316 event idx
#
# emptyNet = True
#  i  10748
#  game_id 2019020170
# 288 event idx
#
# emptyNet = True
#  i  11004
#  game_id 2019020174
# 338 event idx
#
# emptyNet = True
#  i  11468
#  game_id 2019020181
# 347 event idx
#
# emptyNet = True
#  i  11652
#  game_id 2019020184
# 273 event idx
#
# emptyNet = True
#  i  11783
#  game_id 2019020186
# 297 event idx
#
# emptyNet = True
#  i  11851
#  game_id 2019020187
# 334 event idx
#
# emptyNet = True
#  i  12491
#  game_id 2019020197
# 307 event idx
#
# emptyNet = True
#  i  12621
#  game_id 2019020199
# 280 event idx
#
# emptyNet = True
#  i  13344
#  game_id 2019020210
# 312 event idx
#
# emptyNet = True
#  i  13415
#  game_id 2019020211
# 291 event idx
#
# emptyNet = True
#  i  13490
#  game_id 2019020212
# 326 event idx
#
# emptyNet = True
#  i  14004
#  game_id 2019020220
# 314 event idx
#
# emptyNet = True
#  i  14790
#  game_id 2019020233
# 292 event idx
#
# emptyNet = True
#  i  14843
#  game_id 2019020234
# 287 event idx
#
# emptyNet = True
#  i  14909
#  game_id 2019020235
# 320 event idx
#
# emptyNet = True
#  i  14969
#  game_id 2019020236
# 323 event idx
#
# emptyNet = True
#  i  14970
#  game_id 2019020236
# 325 event idx
#
# emptyNet = True
#  i  15307
#  game_id 2019020241
# 309 event idx
#
# emptyNet = True
#  i  15442
#  game_id 2019020243
# 312 event idx
#
# emptyNet = True
#  i  15444
#  game_id 2019020243
# 326 event idx
#
# emptyNet = True
#  i  15754
#  game_id 2019020248
# 332 event idx
#
# emptyNet = True
#  i  15877
#  game_id 2019020250
# 282 event idx
#
# emptyNet = True
#  i  16448
#  game_id 2019020258
# 318 event idx
#
# emptyNet = True
#  i  17692
#  game_id 2019020277
# 305 event idx
#
# emptyNet = True
#  i  17818
#  game_id 2019020279
# 310 event idx
#
# emptyNet = True
#  i  17915
#  game_id 2019020281
# 263 event idx
#
# emptyNet = True
#  i  17968
#  game_id 2019020282
# 319 event idx
#
# emptyNet = True
#  i  18100
#  game_id 2019020284
# 317 event idx
#
# emptyNet = True
#  i  18735
#  game_id 2019020294
# 368 event idx
#
# emptyNet = True
#  i  18863
#  game_id 2019020296
# 328 event idx
#
# emptyNet = True
#  i  19096
#  game_id 2019020300
# 266 event idx
#
# emptyNet = True
#  i  19231
#  game_id 2019020302
# 302 event idx
#
# emptyNet = True
#  i  19362
#  game_id 2019020304
# 285 event idx
#
# emptyNet = True
#  i  19704
#  game_id 2019020309
# 277 event idx
#
# emptyNet = True
#  i  20129
#  game_id 2019020316
# 309 event idx
#
# emptyNet = True
#  i  20243
#  game_id 2019020318
# 236 event idx
#
# emptyNet = True
#  i  20308
#  game_id 2019020319
# 285 event idx
#
# emptyNet = True
#  i  20616
#  game_id 2019020324
# 331 event idx
#
# emptyNet = True
#  i  20745
#  game_id 2019020326
# 337 event idx
#
# emptyNet = True
#  i  20938
#  game_id 2019020329
# 356 event idx
#
# emptyNet = True
#  i  21358
#  game_id 2019020336
# 282 event idx
#
# emptyNet = True
#  i  21560
#  game_id 2019020339
# 314 event idx
#
# emptyNet = True
#  i  21689
#  game_id 2019020341
# 345 event idx
#
# emptyNet = True
#  i  21751
#  game_id 2019020342
# 300 event idx
#
# emptyNet = True
#  i  22296
#  game_id 2019020350
# 286 event idx
#
# emptyNet = True
#  i  22565
#  game_id 2019020354
# 265 event idx
#
# emptyNet = True
#  i  22625
#  game_id 2019020355
# 288 event idx
#
# emptyNet = True
#  i  22758
#  game_id 2019020357
# 329 event idx
#
# emptyNet = True
#  i  22827
#  game_id 2019020358
# 310 event idx
#
# emptyNet = True
#  i  23147
#  game_id 2019020363
# 287 event idx
#
# emptyNet = True
#  i  23931
#  game_id 2019020376
# 334 event idx
#
# emptyNet = True
#  i  24331
#  game_id 2019020382
# 351 event idx
#
# emptyNet = True
#  i  24701
#  game_id 2019020388
# 299 event idx
#
# emptyNet = True
#  i  24758
#  game_id 2019020389
# 271 event idx
#
# emptyNet = True
#  i  24842
#  game_id 2019020390
# 372 event idx
#
# emptyNet = True
#  i  24962
#  game_id 2019020392
# 239 event idx
#
# emptyNet = True
#  i  25466
#  game_id 2019020400
# 285 event idx
#
# emptyNet = True
#  i  25598
#  game_id 2019020402
# 360 event idx
#
# emptyNet = True
#  i  25653
#  game_id 2019020403
# 289 event idx
#
# emptyNet = True
#  i  25855
#  game_id 2019020406
# 286 event idx
#
# emptyNet = True
#  i  25858
#  game_id 2019020406
# 293 event idx
#
# emptyNet = True
#  i  26093
#  game_id 2019020410
# 297 event idx
#
# emptyNet = True
#  i  26207
#  game_id 2019020412
# 244 event idx
#
# emptyNet = True
#  i  26906
#  game_id 2019020423
# 307 event idx
#
# emptyNet = True
#  i  27027
#  game_id 2019020425
# 345 event idx
#
# emptyNet = True
#  i  27099
#  game_id 2019020426
# 304 event idx
#
# emptyNet = True
#  i  27217
#  game_id 2019020428
# 271 event idx
#
# emptyNet = True
#  i  27282
#  game_id 2019020429
# 250 event idx
#
# emptyNet = True
#  i  27598
#  game_id 2019020434
# 309 event idx
#
# emptyNet = True
#  i  27755
#  game_id 2019020437
# 295 event idx
#
# emptyNet = True
#  i  28067
#  game_id 2019020442
# 299 event idx
#
# emptyNet = True
#  i  28522
#  game_id 2019020449
# 325 event idx
#
# emptyNet = True
#  i  28792
#  game_id 2019020454
# 284 event idx
#
# emptyNet = True
#  i  28848
#  game_id 2019020455
# 286 event idx
#
# emptyNet = True
#  i  28981
#  game_id 2019020457
# 276 event idx
#
# emptyNet = True
#  i  29048
#  game_id 2019020458
# 318 event idx
#
# emptyNet = True
#  i  29439
#  game_id 2019020464
# 278 event idx
#
# emptyNet = True
#  i  29764
#  game_id 2019020469
# 321 event idx
#
# emptyNet = True
#  i  29826
#  game_id 2019020470
# 305 event idx
#
# emptyNet = True
#  i  29833
#  game_id 2019020470
# 328 event idx
#
# emptyNet = True
#  i  29960
#  game_id 2019020472
# 245 event idx
#
# emptyNet = True
#  i  29961
#  game_id 2019020472
# 253 event idx
#
# emptyNet = True
#  i  30094
#  game_id 2019020474
# 359 event idx
#
# emptyNet = True
#  i  30153
#  game_id 2019020475
# 287 event idx
#
# emptyNet = True
#  i  30530
#  game_id 2019020481
# 260 event idx
#
# emptyNet = True
#  i  30654
#  game_id 2019020483
# 290 event idx
#
# emptyNet = True
#  i  31031
#  game_id 2019020489
# 318 event idx
#
# emptyNet = True
#  i  31140
#  game_id 2019020491
# 318 event idx
#
# emptyNet = True
#  i  31568
#  game_id 2019020498
# 284 event idx
#
# emptyNet = True
#  i  31705
#  game_id 2019020500
# 320 event idx
#
# emptyNet = True
#  i  31897
#  game_id 2019020503
# 305 event idx
#
# emptyNet = True
#  i  32164
#  game_id 2019020507
# 263 event idx
#
# emptyNet = True
#  i  32238
#  game_id 2019020508
# 347 event idx
#
# emptyNet = True
#  i  32353
#  game_id 2019020510
# 207 event idx
#
# emptyNet = True
#  i  32423
#  game_id 2019020511
# 329 event idx
#
# emptyNet = True
#  i  32608
#  game_id 2019020514
# 289 event idx
#
# emptyNet = True
#  i  32612
#  game_id 2019020514
# 298 event idx
#
# emptyNet = True
#  i  32777
#  game_id 2019020517
# 289 event idx
#
# emptyNet = True
#  i  32977
#  game_id 2019020520
# 325 event idx
#
# emptyNet = True
#  i  32979
#  game_id 2019020520
# 336 event idx
#
# emptyNet = True
#  i  33091
#  game_id 2019020522
# 270 event idx
#
# emptyNet = True
#  i  33283
#  game_id 2019020525
# 283 event idx
#
# emptyNet = True
#  i  33480
#  game_id 2019020528
# 299 event idx
#
# emptyNet = True
#  i  33540
#  game_id 2019020529
# 278 event idx
#
# emptyNet = True
#  i  33664
#  game_id 2019020531
# 298 event idx
#
# emptyNet = True
#  i  33665
#  game_id 2019020531
# 301 event idx
#
# emptyNet = True
#  i  33949
#  game_id 2019020536
# 334 event idx
#
# emptyNet = True
#  i  34454
#  game_id 2019020544
# 308 event idx
#
# emptyNet = True
#  i  34597
#  game_id 2019020546
# 328 event idx
#
# emptyNet = True
#  i  34908
#  game_id 2019020551
# 289 event idx
#
# emptyNet = True
#  i  34964
#  game_id 2019020552
# 234 event idx
#
# emptyNet = True
#  i  35344
#  game_id 2019020558
# 344 event idx
#
# emptyNet = True
#  i  35473
#  game_id 2019020560
# 275 event idx
#
# emptyNet = True
#  i  35474
#  game_id 2019020560
# 279 event idx
#
# emptyNet = True
#  i  35589
#  game_id 2019020562
# 293 event idx
#
# emptyNet = True
#  i  35695
#  game_id 2019020564
# 281 event idx
#
# emptyNet = True
#  i  35696
#  game_id 2019020564
# 288 event idx
#
# emptyNet = True
#  i  35889
#  game_id 2019020567
# 301 event idx
#
# emptyNet = True
#  i  36040
#  game_id 2019020569
# 315 event idx
#
# emptyNet = True
#  i  36097
#  game_id 2019020570
# 283 event idx
#
# emptyNet = True
#  i  36154
#  game_id 2019020571
# 298 event idx
#
# emptyNet = True
#  i  36158
#  game_id 2019020571
# 313 event idx
#
# shooter_count not equal to goalie_count
# i  36431
# game_id 2019020575
# 335 event idx
#
# score, not emptyNet, but no goalie! Add goalie as pd.NA
# emptyNet = True
#  i  36713
#  game_id 2019020579
# 267 event idx
#
# emptyNet = True
#  i  36891
#  game_id 2019020582
# 260 event idx
#
# emptyNet = True
#  i  37283
#  game_id 2019020588
# 298 event idx
#
# emptyNet = True
#  i  37836
#  game_id 2019020596
# 346 event idx
#
# emptyNet = True
#  i  37889
#  game_id 2019020597
# 286 event idx
#
# emptyNet = True
#  i  38233
#  game_id 2019020602
# 286 event idx
#
# emptyNet = True
#  i  38653
#  game_id 2019020609
# 319 event idx
#
# emptyNet = True
#  i  38770
#  game_id 2019020611
# 330 event idx
#
# emptyNet = True
#  i  39046
#  game_id 2019020615
# 311 event idx
#
# emptyNet = True
#  i  39102
#  game_id 2019020616
# 286 event idx
#
# emptyNet = True
#  i  39157
#  game_id 2019020617
# 261 event idx
#
# emptyNet = True
#  i  39220
#  game_id 2019020618
# 344 event idx
#
# emptyNet = True
#  i  39344
#  game_id 2019020620
# 301 event idx
#
# emptyNet = True
#  i  39411
#  game_id 2019020621
# 304 event idx
#
# emptyNet = True
#  i  39414
#  game_id 2019020621
# 312 event idx
#
# emptyNet = True
#  i  39491
#  game_id 2019020622
# 370 event idx
#
# emptyNet = True
#  i  39554
#  game_id 2019020623
# 362 event idx
#
# emptyNet = True
#  i  39619
#  game_id 2019020624
# 293 event idx
#
# emptyNet = True
#  i  40119
#  game_id 2019020632
# 333 event idx
#
# emptyNet = True
#  i  40452
#  game_id 2019020637
# 315 event idx
#
# emptyNet = True
#  i  40640
#  game_id 2019020640
# 266 event idx
#
# emptyNet = True
#  i  40704
#  game_id 2019020641
# 320 event idx
#
# emptyNet = True
#  i  40991
#  game_id 2019020646
# 273 event idx
#
# emptyNet = True
#  i  41114
#  game_id 2019020648
# 323 event idx
#
# emptyNet = True
#  i  41178
#  game_id 2019020649
# 274 event idx
#
# emptyNet = True
#  i  41224
#  game_id 2019020650
# 301 event idx
#
# emptyNet = True
#  i  41408
#  game_id 2019020653
# 294 event idx
#
# emptyNet = True
#  i  41478
#  game_id 2019020654
# 285 event idx
#
# emptyNet = True
#  i  41667
#  game_id 2019020657
# 306 event idx
#
# emptyNet = True
#  i  42002
#  game_id 2019020662
# 254 event idx
#
# emptyNet = True
#  i  42139
#  game_id 2019020664
# 348 event idx
#
# emptyNet = True
#  i  42277
#  game_id 2019020666
# 305 event idx
#
# emptyNet = True
#  i  42582
#  game_id 2019020671
# 310 event idx
#
# emptyNet = True
#  i  42756
#  game_id 2019020674
# 267 event idx
#
# emptyNet = True
#  i  43060
#  game_id 2019020679
# 309 event idx
#
# emptyNet = True
#  i  43336
#  game_id 2019020683
# 259 event idx
#
# emptyNet = True
#  i  43398
#  game_id 2019020684
# 331 event idx
#
# emptyNet = True
#  i  43399
#  game_id 2019020684
# 333 event idx
#
# emptyNet = True
#  i  43600
#  game_id 2019020687
# 289 event idx
#
# emptyNet = True
#  i  43912
#  game_id 2019020692
# 253 event idx
#
# emptyNet = True
#  i  44154
#  game_id 2019020696
# 286 event idx
#
# emptyNet = True
#  i  44230
#  game_id 2019020697
# 339 event idx
#
# emptyNet = True
#  i  44634
#  game_id 2019020704
# 248 event idx
#
# emptyNet = True
#  i  44879
#  game_id 2019020708
# 270 event idx
#
# emptyNet = True
#  i  45255
#  game_id 2019020714
# 265 event idx
#
# emptyNet = True
#  i  45317
#  game_id 2019020715
# 322 event idx
#
# emptyNet = True
#  i  45700
#  game_id 2019020721
# 286 event idx
#
# emptyNet = True
#  i  45841
#  game_id 2019020723
# 327 event idx
#
# emptyNet = True
#  i  45906
#  game_id 2019020724
# 286 event idx
#
# emptyNet = True
#  i  45909
#  game_id 2019020724
# 296 event idx
#
# emptyNet = True
#  i  46087
#  game_id 2019020727
# 317 event idx
#
# emptyNet = True
#  i  46722
#  game_id 2019020737
# 310 event idx
#
# emptyNet = True
#  i  46724
#  game_id 2019020737
# 320 event idx
#
# emptyNet = True
#  i  46847
#  game_id 2019020739
# 264 event idx
#
# emptyNet = True
#  i  47094
#  game_id 2019020743
# 299 event idx
#
# emptyNet = True
#  i  47136
#  game_id 2019020744
# 263 event idx
#
# emptyNet = True
#  i  47186
#  game_id 2019020745
# 280 event idx
#
# emptyNet = True
#  i  47253
#  game_id 2019020746
# 274 event idx
#
# emptyNet = True
#  i  47462
#  game_id 2019020749
# 302 event idx
#
# emptyNet = True
#  i  48041
#  game_id 2019020758
# 329 event idx
#
# emptyNet = True
#  i  48112
#  game_id 2019020759
# 324 event idx
#
# emptyNet = True
#  i  48345
#  game_id 2019020763
# 291 event idx
#
# emptyNet = True
#  i  48644
#  game_id 2019020768
# 345 event idx
#
# emptyNet = True
#  i  48806
#  game_id 2019020770
# 272 event idx
#
# emptyNet = True
#  i  48929
#  game_id 2019020772
# 313 event idx
#
# emptyNet = True
#  i  49054
#  game_id 2019020774
# 274 event idx
#
# emptyNet = True
#  i  49057
#  game_id 2019020774
# 286 event idx
#
# emptyNet = True
#  i  49251
#  game_id 2019020777
# 327 event idx
#
# emptyNet = True
#  i  49433
#  game_id 2019020780
# 346 event idx
#
# emptyNet = True
#  i  49497
#  game_id 2019020781
# 288 event idx
#
# emptyNet = True
#  i  49547
#  game_id 2019020782
# 279 event idx
#
# emptyNet = True
#  i  49861
#  game_id 2019020787
# 318 event idx
#
# emptyNet = True
#  i  50050
#  game_id 2019020790
# 362 event idx
#
# emptyNet = True
#  i  50519
#  game_id 2019020798
# 331 event idx
#
# emptyNet = True
#  i  50589
#  game_id 2019020799
# 303 event idx
#
# emptyNet = True
#  i  50592
#  game_id 2019020799
# 314 event idx
#
# emptyNet = True
#  i  50650
#  game_id 2019020800
# 292 event idx
#
# emptyNet = True
#  i  51015
#  game_id 2019020805
# 326 event idx
#
# emptyNet = True
#  i  51136
#  game_id 2019020807
# 296 event idx
#
# shooter_count not equal to goalie_count
# i  51266
# game_id 2019020809
# 278 event idx
#
# score, not emptyNet, but no goalie! Add goalie as pd.NA
# emptyNet = True
#  i  51370
#  game_id 2019020811
# 259 event idx
#
# emptyNet = True
#  i  51535
#  game_id 2019020814
# 308 event idx
#
# emptyNet = True
#  i  51723
#  game_id 2019020817
# 263 event idx
#
# emptyNet = True
#  i  52166
#  game_id 2019020824
# 273 event idx
#
# emptyNet = True
#  i  52233
#  game_id 2019020825
# 328 event idx
#
# emptyNet = True
#  i  52476
#  game_id 2019020829
# 337 event idx
#
# emptyNet = True
#  i  52598
#  game_id 2019020831
# 308 event idx
#
# emptyNet = True
#  i  52785
#  game_id 2019020834
# 293 event idx
#
# emptyNet = True
#  i  53048
#  game_id 2019020838
# 288 event idx
#
# emptyNet = True
#  i  53239
#  game_id 2019020841
# 256 event idx
#
# emptyNet = True
#  i  53427
#  game_id 2019020844
# 294 event idx
#
# emptyNet = True
#  i  53528
#  game_id 2019020846
# 277 event idx
#
# emptyNet = True
#  i  53948
#  game_id 2019020853
# 273 event idx
#
# emptyNet = True
#  i  54082
#  game_id 2019020855
# 300 event idx
#
# emptyNet = True
#  i  54221
#  game_id 2019020857
# 337 event idx
#
# emptyNet = True
#  i  54288
#  game_id 2019020858
# 297 event idx
#
# emptyNet = True
#  i  54289
#  game_id 2019020858
# 301 event idx
#
# emptyNet = True
#  i  54484
#  game_id 2019020861
# 319 event idx
#
# emptyNet = True
#  i  55007
#  game_id 2019020869
# 274 event idx
#
# shooter_count not equal to goalie_count
# i  55270
# game_id 2019020873
# 322 event idx
#
# score, not emptyNet, but no goalie! Add goalie as pd.NA
# emptyNet = True
#  i  55340
#  game_id 2019020874
# 316 event idx
#
# emptyNet = True
#  i  55412
#  game_id 2019020875
# 317 event idx
#
# shooter_count not equal to goalie_count
# i  55413
# game_id 2019020876
# 2 event idx
#
# score, not emptyNet, but no goalie! Add goalie as pd.NA
# shooter_count not equal to goalie_count
# i  55414
# game_id 2019020876
# 3 event idx
#
# score, not emptyNet, but no goalie! Add goalie as pd.NA
# shooter_count not equal to goalie_count
# i  55477
# game_id 2019020876
# 316 event idx
#
# score, not emptyNet, but no goalie! Add goalie as pd.NA
# emptyNet = True
#  i  55478
#  game_id 2019020876
# 318 event idx
#
# emptyNet = True
#  i  55545
#  game_id 2019020877
# 308 event idx
#
# emptyNet = True
#  i  55616
#  game_id 2019020878
# 331 event idx
#
# emptyNet = True
#  i  55684
#  game_id 2019020879
# 297 event idx
#
# emptyNet = True
#  i  55859
#  game_id 2019020882
# 323 event idx
#
# emptyNet = True
#  i  56435
#  game_id 2019020891
# 292 event idx
#
# emptyNet = True
#  i  56501
#  game_id 2019020892
# 260 event idx
#
# emptyNet = True
#  i  56813
#  game_id 2019020897
# 305 event idx
#
# emptyNet = True
#  i  56873
#  game_id 2019020898
# 290 event idx
#
# emptyNet = True
#  i  56876
#  game_id 2019020898
# 296 event idx
#
# emptyNet = True
#  i  56936
#  game_id 2019020899
# 283 event idx
#
# emptyNet = True
#  i  57049
#  game_id 2019020901
# 288 event idx
#
# emptyNet = True
#  i  57108
#  game_id 2019020902
# 297 event idx
#
# emptyNet = True
#  i  57244
#  game_id 2019020904
# 350 event idx
#
# emptyNet = True
#  i  57430
#  game_id 2019020907
# 338 event idx
#
# emptyNet = True
#  i  57991
#  game_id 2019020915
# 309 event idx
#
# emptyNet = True
#  i  58113
#  game_id 2019020917
# 293 event idx
#
# emptyNet = True
#  i  58394
#  game_id 2019020922
# 319 event idx
#
# emptyNet = True
#  i  58624
#  game_id 2019020926
# 247 event idx
#
# emptyNet = True
#  i  58967
#  game_id 2019020931
# 294 event idx
#
# emptyNet = True
#  i  59598
#  game_id 2019020941
# 337 event idx
#
# emptyNet = True
#  i  59663
#  game_id 2019020942
# 295 event idx
#
# emptyNet = True
#  i  59895
#  game_id 2019020946
# 308 event idx
#
# emptyNet = True
#  i  60672
#  game_id 2019020957
# 335 event idx
#
# emptyNet = True
#  i  60787
#  game_id 2019020959
# 366 event idx
#
# emptyNet = True
#  i  60960
#  game_id 2019020962
# 325 event idx
#
# emptyNet = True
#  i  61020
#  game_id 2019020963
# 278 event idx
#
# emptyNet = True
#  i  61191
#  game_id 2019020966
# 275 event idx
#
# emptyNet = True
#  i  61327
#  game_id 2019020968
# 356 event idx
#
# emptyNet = True
#  i  62414
#  game_id 2019020985
# 320 event idx
#
# emptyNet = True
#  i  62479
#  game_id 2019020986
# 266 event idx
#
# emptyNet = True
#  i  62535
#  game_id 2019020987
# 273 event idx
#
# emptyNet = True
#  i  62594
#  game_id 2019020988
# 309 event idx
#
# emptyNet = True
#  i  62836
#  game_id 2019020992
# 282 event idx
#
# emptyNet = True
#  i  63148
#  game_id 2019020997
# 314 event idx
#
# emptyNet = True
#  i  63511
#  game_id 2019021003
# 305 event idx
#
# emptyNet = True
#  i  63778
#  game_id 2019021007
# 271 event idx
#
# emptyNet = True
#  i  63837
#  game_id 2019021008
# 293 event idx
#
# emptyNet = True
#  i  64154
#  game_id 2019021013
# 328 event idx
#
# emptyNet = True
#  i  64564
#  game_id 2019021020
# 295 event idx
#
# emptyNet = True
#  i  64615
#  game_id 2019021021
# 256 event idx
#
# emptyNet = True
#  i  65081
#  game_id 2019021028
# 296 event idx
#
# emptyNet = True
#  i  65338
#  game_id 2019021032
# 325 event idx
#
# emptyNet = True
#  i  66046
#  game_id 2019021043
# 321 event idx
#
# emptyNet = True
#  i  66279
#  game_id 2019021047
# 318 event idx
#
# emptyNet = True
#  i  66573
#  game_id 2019021052
# 263 event idx
#
# emptyNet = True
#  i  66636
#  game_id 2019021053
# 318 event idx
#
# emptyNet = True
#  i  66701
#  game_id 2019021054
# 310 event idx
#
# emptyNet = True
#  i  66765
#  game_id 2019021055
# 314 event idx
#
# emptyNet = True
#  i  66970
#  game_id 2019021058
# 335 event idx
#
# emptyNet = True
#  i  67216
#  game_id 2019021062
# 297 event idx
#
# emptyNet = True
#  i  67516
#  game_id 2019021067
# 313 event idx
#
# emptyNet = True
#  i  67839
#  game_id 2019021072
# 291 event idx
#
# emptyNet = True
#  i  68374
#  game_id 2019021080
# 260 event idx
#
# emptyNet = True
#  i  68839
#  game_id 2019030006
# 330 event idx
#
# emptyNet = True
#  i  68969
#  game_id 2019030012
# 343 event idx
#
# emptyNet = True
#  i  69356
#  game_id 2019030022
# 318 event idx
#
# emptyNet = True
#  i  69465
#  game_id 2019030024
# 338 event idx
#
# emptyNet = True
#  i  69654
#  game_id 2019030033
# 351 event idx
#
# emptyNet = True
#  i  69880
#  game_id 2019030044
# 365 event idx
#
# emptyNet = True
#  i  69943
#  game_id 2019030051
# 339 event idx
#
# emptyNet = True
#  i  70001
#  game_id 2019030052
# 320 event idx
#
# emptyNet = True
#  i  70228
#  game_id 2019030055
# 275 event idx
#
# emptyNet = True
#  i  70687
#  game_id 2019030073
# 350 event idx
#
# emptyNet = True
#  i  70834
#  game_id 2019030081
# 330 event idx
#
# emptyNet = True
#  i  71062
#  game_id 2019030091
# 317 event idx
#
# emptyNet = True
#  i  71187
#  game_id 2019030093
# 337 event idx
#
# emptyNet = True
#  i  71249
#  game_id 2019030094
# 379 event idx
#
# emptyNet = True
#  i  71250
#  game_id 2019030094
# 382 event idx
#
# emptyNet = True
#  i  71529
#  game_id 2019030115
# 348 event idx
#
# emptyNet = True
#  i  72065
#  game_id 2019030132
# 346 event idx
#
# emptyNet = True
#  i  72216
#  game_id 2019030135
# 296 event idx
#
# emptyNet = True
#  i  72217
#  game_id 2019030135
# 301 event idx
#
# emptyNet = True
#  i  72415
#  game_id 2019030143
# 348 event idx
#
# emptyNet = True
#  i  72763
#  game_id 2019030154
# 374 event idx
#
# emptyNet = True
#  i  73014
#  game_id 2019030163
# 361 event idx
#
# emptyNet = True
#  i  73017
#  game_id 2019030163
# 372 event idx
#
# emptyNet = True
#  i  73917
#  game_id 2019030186
# 355 event idx
#
# emptyNet = True
#  i  73969
#  game_id 2019030211
# 300 event idx
#
# emptyNet = True
#  i  74357
#  game_id 2019030217
# 302 event idx
#
# emptyNet = True
#  i  74815
#  game_id 2019030232
# 393 event idx
#
# emptyNet = True
#  i  75072
#  game_id 2019030236
# 340 event idx
#
# emptyNet = True
#  i  75123
#  game_id 2019030237
# 345 event idx
#
# emptyNet = True
#  i  75125
#  game_id 2019030237
# 354 event idx
#
# emptyNet = True
#  i  75253
#  game_id 2019030242
# 376 event idx
#
# emptyNet = True
#  i  75321
#  game_id 2019030243
# 426 event idx
#
# emptyNet = True
#  i  75514
#  game_id 2019030246
# 337 event idx
#
# shooter_count not equal to goalie_count
# i  75774
# game_id 2019030313
# 403 event idx
#
# score, not emptyNet, but no goalie! Add goalie as pd.NA
# emptyNet = True
#  i  75835
#  game_id 2019030314
# 359 event idx
#
# emptyNet = True
#  i  76311
#  game_id 2019030411
# 350 event idx
#
# 76620
# 76620
# 76620
# 76620
# 76620
# 76620
# 76620
# 76620
# 76620
# 76620
# 76620
# 76620

# %%
d2
# Out:
#           game_id event_idx period periodTime             teamInfo isGoal  \
# 0      2019020001         4      1      00:25      Ottawa Senators   True
# 1      2019020001        12      1      01:31  Toronto Maple Leafs  False
# 2      2019020001        19      1      03:23      Ottawa Senators  False
# 3      2019020001        22      1      03:56  Toronto Maple Leafs  False
# 4      2019020001        27      1      04:47  Toronto Maple Leafs  False
# ...           ...       ...    ...        ...                  ...    ...
# 76615  2019030416       319      3      16:01  Tampa Bay Lightning  False
# 76616  2019030416       326      3      17:20  Tampa Bay Lightning  False
# 76617  2019030416       333      3      18:50         Dallas Stars  False
# 76618  2019030416       341      3      19:27         Dallas Stars  False
# 76619  2019030416       343      3      19:45         Dallas Stars  False
#
#          shotType coordinates_x coordinates_y          shooter  \
# 0          Tip-In          85.0          -1.0    Brady Tkachuk
# 1       Snap Shot         -32.0          -2.0    Morgan Rielly
# 2       Snap Shot          63.0          -6.0     Dylan DeMelo
# 3      Wrist Shot         -59.0         -20.0    Morgan Rielly
# 4       Slap Shot         -42.0         -29.0     Tyson Barrie
# ...           ...           ...           ...              ...
# 76615   Snap Shot         -59.0         -24.0  Anthony Cirelli
# 76616  Wrist Shot         -81.0           3.0    Blake Coleman
# 76617   Snap Shot          34.0          -6.0   John Klingberg
# 76618  Wrist Shot          31.0          10.0   John Klingberg
# 76619  Wrist Shot          77.0           0.0     Joe Pavelski
#
#                    goalie emptyNet strength
# 0       Frederik Andersen    False     EVEN
# 1          Craig Anderson    False       NA
# 2       Frederik Andersen    False       NA
# 3          Craig Anderson    False       NA
# 4          Craig Anderson    False       NA
# ...                   ...      ...      ...
# 76615      Anton Khudobin    False       NA
# 76616      Anton Khudobin    False       NA
# 76617  Andrei Vasilevskiy    False       NA
# 76618  Andrei Vasilevskiy    False       NA
# 76619  Andrei Vasilevskiy    False       NA
#
# [76620 rows x 13 columns]

# %%
d2020 = tidyData(df_2020)
# Out:
# emptyNet = True
#  i  361
#  game_id 2020020006
# 265 event idx
#
# emptyNet = True
#  i  558
#  game_id 2020020009
# 322 event idx
#
# emptyNet = True
#  i  615
#  game_id 2020020010
# 300 event idx
#
# emptyNet = True
#  i  680
#  game_id 2020020011
# 298 event idx
#
# emptyNet = True
#  i  954
#  game_id 2020020015
# 297 event idx
#
# emptyNet = True
#  i  1119
#  game_id 2020020018
# 263 event idx
#
# emptyNet = True
#  i  1538
#  game_id 2020020025
# 276 event idx
#
# emptyNet = True
#  i  2044
#  game_id 2020020033
# 254 event idx
#
# emptyNet = True
#  i  2046
#  game_id 2020020033
# 261 event idx
#
# emptyNet = True
#  i  2452
#  game_id 2020020040
# 229 event idx
#
# emptyNet = True
#  i  2520
#  game_id 2020020041
# 309 event idx
#
# emptyNet = True
#  i  2579
#  game_id 2020020042
# 265 event idx
#
# emptyNet = True
#  i  2699
#  game_id 2020020044
# 336 event idx
#
# emptyNet = True
#  i  2907
#  game_id 2020020047
# 323 event idx
#
# emptyNet = True
#  i  3205
#  game_id 2020020052
# 292 event idx
#
# emptyNet = True
#  i  3438
#  game_id 2020020056
# 255 event idx
#
# emptyNet = True
#  i  4061
#  game_id 2020020066
# 274 event idx
#
# emptyNet = True
#  i  4250
#  game_id 2020020069
# 288 event idx
#
# emptyNet = True
#  i  4315
#  game_id 2020020070
# 306 event idx
#
# emptyNet = True
#  i  4372
#  game_id 2020020071
# 279 event idx
#
# emptyNet = True
#  i  4373
#  game_id 2020020071
# 281 event idx
#
# emptyNet = True
#  i  4492
#  game_id 2020020073
# 288 event idx
#
# emptyNet = True
#  i  4713
#  game_id 2020020077
# 277 event idx
#
# emptyNet = True
#  i  4767
#  game_id 2020020078
# 248 event idx
#
# emptyNet = True
#  i  4824
#  game_id 2020020079
# 276 event idx
#
# emptyNet = True
#  i  4877
#  game_id 2020020080
# 298 event idx
#
# emptyNet = True
#  i  5193
#  game_id 2020020085
# 333 event idx
#
# emptyNet = True
#  i  5399
#  game_id 2020020088
# 307 event idx
#
# emptyNet = True
#  i  5529
#  game_id 2020020091
# 284 event idx
#
# emptyNet = True
#  i  5775
#  game_id 2020020095
# 264 event idx
#
# emptyNet = True
#  i  5915
#  game_id 2020020097
# 358 event idx
#
# emptyNet = True
#  i  6094
#  game_id 2020020100
# 266 event idx
#
# emptyNet = True
#  i  6802
#  game_id 2020020112
# 265 event idx
#
# emptyNet = True
#  i  7217
#  game_id 2020020119
# 256 event idx
#
# emptyNet = True
#  i  7911
#  game_id 2020020131
# 333 event idx
#
# emptyNet = True
#  i  7974
#  game_id 2020020132
# 289 event idx
#
# emptyNet = True
#  i  8212
#  game_id 2020020136
# 307 event idx
#
# emptyNet = True
#  i  8710
#  game_id 2020020144
# 291 event idx
#
# emptyNet = True
#  i  8768
#  game_id 2020020145
# 292 event idx
#
# emptyNet = True
#  i  8828
#  game_id 2020020146
# 262 event idx
#
# emptyNet = True
#  i  9192
#  game_id 2020020152
# 241 event idx
#
# emptyNet = True
#  i  9415
#  game_id 2020020155
# 343 event idx
#
# emptyNet = True
#  i  9749
#  game_id 2020020161
# 275 event idx
#
# emptyNet = True
#  i  9940
#  game_id 2020020164
# 300 event idx
#
# emptyNet = True
#  i  10201
#  game_id 2020020168
# 349 event idx
#
# emptyNet = True
#  i  10270
#  game_id 2020020169
# 266 event idx
#
# emptyNet = True
#  i  10440
#  game_id 2020020172
# 261 event idx
#
# emptyNet = True
#  i  10498
#  game_id 2020020173
# 267 event idx
#
# emptyNet = True
#  i  10605
#  game_id 2020020175
# 236 event idx
#
# emptyNet = True
#  i  11407
#  game_id 2020020188
# 262 event idx
#
# emptyNet = True
#  i  11483
#  game_id 2020020189
# 303 event idx
#
# emptyNet = True
#  i  11990
#  game_id 2020020198
# 269 event idx
#
# emptyNet = True
#  i  11994
#  game_id 2020020198
# 282 event idx
#
# emptyNet = True
#  i  12057
#  game_id 2020020199
# 301 event idx
#
# emptyNet = True
#  i  12936
#  game_id 2020020213
# 285 event idx
#
# emptyNet = True
#  i  13187
#  game_id 2020020217
# 296 event idx
#
# emptyNet = True
#  i  13621
#  game_id 2020020224
# 358 event idx
#
# emptyNet = True
#  i  13674
#  game_id 2020020225
# 299 event idx
#
# emptyNet = True
#  i  14382
#  game_id 2020020237
# 311 event idx
#
# emptyNet = True
#  i  14574
#  game_id 2020020240
# 293 event idx
#
# emptyNet = True
#  i  14638
#  game_id 2020020241
# 284 event idx
#
# emptyNet = True
#  i  14711
#  game_id 2020020242
# 304 event idx
#
# emptyNet = True
#  i  14712
#  game_id 2020020242
# 308 event idx
#
# emptyNet = True
#  i  15340
#  game_id 2020020253
# 251 event idx
#
# emptyNet = True
#  i  15777
#  game_id 2020020260
# 283 event idx
#
# emptyNet = True
#  i  15833
#  game_id 2020020261
# 261 event idx
#
# emptyNet = True
#  i  16204
#  game_id 2020020267
# 316 event idx
#
# emptyNet = True
#  i  16256
#  game_id 2020020268
# 274 event idx
#
# emptyNet = True
#  i  16450
#  game_id 2020020271
# 298 event idx
#
# emptyNet = True
#  i  16614
#  game_id 2020020274
# 297 event idx
#
# emptyNet = True
#  i  16794
#  game_id 2020020277
# 265 event idx
#
# emptyNet = True
#  i  16901
#  game_id 2020020279
# 263 event idx
#
# emptyNet = True
#  i  17457
#  game_id 2020020288
# 262 event idx
#
# emptyNet = True
#  i  17620
#  game_id 2020020291
# 314 event idx
#
# emptyNet = True
#  i  17902
#  game_id 2020020295
# 309 event idx
#
# emptyNet = True
#  i  17955
#  game_id 2020020296
# 232 event idx
#
# emptyNet = True
#  i  18016
#  game_id 2020020297
# 297 event idx
#
# emptyNet = True
#  i  18373
#  game_id 2020020303
# 335 event idx
#
# emptyNet = True
#  i  19025
#  game_id 2020020313
# 306 event idx
#
# emptyNet = True
#  i  19026
#  game_id 2020020313
# 309 event idx
#
# emptyNet = True
#  i  19081
#  game_id 2020020314
# 260 event idx
#
# emptyNet = True
#  i  19207
#  game_id 2020020316
# 256 event idx
#
# emptyNet = True
#  i  19274
#  game_id 2020020317
# 264 event idx
#
# emptyNet = True
#  i  19390
#  game_id 2020020319
# 269 event idx
#
# emptyNet = True
#  i  19456
#  game_id 2020020320
# 288 event idx
#
# emptyNet = True
#  i  19840
#  game_id 2020020327
# 264 event idx
#
# emptyNet = True
#  i  20471
#  game_id 2020020337
# 279 event idx
#
# emptyNet = True
#  i  20774
#  game_id 2020020342
# 310 event idx
#
# emptyNet = True
#  i  20954
#  game_id 2020020345
# 252 event idx
#
# emptyNet = True
#  i  21048
#  game_id 2020020347
# 263 event idx
#
# emptyNet = True
#  i  21186
#  game_id 2020020349
# 323 event idx
#
# emptyNet = True
#  i  21379
#  game_id 2020020352
# 327 event idx
#
# emptyNet = True
#  i  21442
#  game_id 2020020353
# 285 event idx
#
# emptyNet = True
#  i  21670
#  game_id 2020020357
# 317 event idx
#
# emptyNet = True
#  i  21740
#  game_id 2020020358
# 286 event idx
#
# emptyNet = True
#  i  21917
#  game_id 2020020361
# 304 event idx
#
# emptyNet = True
#  i  22108
#  game_id 2020020364
# 363 event idx
#
# emptyNet = True
#  i  22168
#  game_id 2020020365
# 320 event idx
#
# emptyNet = True
#  i  22725
#  game_id 2020020374
# 314 event idx
#
# emptyNet = True
#  i  23502
#  game_id 2020020387
# 314 event idx
#
# emptyNet = True
#  i  23733
#  game_id 2020020391
# 248 event idx
#
# shooter_count not equal to goalie_count
# i  24154
# game_id 2020020398
# 265 event idx
#
# score, not emptyNet, but no goalie! Add goalie as pd.NA
# emptyNet = True
#  i  24558
#  game_id 2020020405
# 357 event idx
#
# emptyNet = True
#  i  24630
#  game_id 2020020406
# 310 event idx
#
# emptyNet = True
#  i  25225
#  game_id 2020020416
# 249 event idx
#
# emptyNet = True
#  i  25335
#  game_id 2020020418
# 290 event idx
#
# emptyNet = True
#  i  25526
#  game_id 2020020421
# 302 event idx
#
# emptyNet = True
#  i  25865
#  game_id 2020020427
# 259 event idx
#
# emptyNet = True
#  i  25930
#  game_id 2020020428
# 287 event idx
#
# emptyNet = True
#  i  26099
#  game_id 2020020431
# 252 event idx
#
# emptyNet = True
#  i  26100
#  game_id 2020020431
# 255 event idx
#
# emptyNet = True
#  i  26271
#  game_id 2020020434
# 231 event idx
#
# emptyNet = True
#  i  26455
#  game_id 2020020437
# 265 event idx
#
# shooter_count not equal to goalie_count
# i  26875
# game_id 2020020444
# 283 event idx
#
# score, not emptyNet, but no goalie! Add goalie as pd.NA
# emptyNet = True
#  i  26938
#  game_id 2020020445
# 270 event idx
#
# emptyNet = True
#  i  27114
#  game_id 2020020448
# 256 event idx
#
# emptyNet = True
#  i  27176
#  game_id 2020020449
# 279 event idx
#
# emptyNet = True
#  i  27177
#  game_id 2020020449
# 283 event idx
#
# emptyNet = True
#  i  27247
#  game_id 2020020450
# 318 event idx
#
# emptyNet = True
#  i  27457
#  game_id 2020020453
# 355 event idx
#
# emptyNet = True
#  i  27859
#  game_id 2020020460
# 261 event idx
#
# emptyNet = True
#  i  28280
#  game_id 2020020467
# 259 event idx
#
# emptyNet = True
#  i  28498
#  game_id 2020020471
# 216 event idx
#
# emptyNet = True
#  i  29469
#  game_id 2020020487
# 294 event idx
#
# emptyNet = True
#  i  29723
#  game_id 2020020491
# 298 event idx
#
# emptyNet = True
#  i  29845
#  game_id 2020020493
# 289 event idx
#
# emptyNet = True
#  i  29906
#  game_id 2020020494
# 280 event idx
#
# emptyNet = True
#  i  30038
#  game_id 2020020496
# 282 event idx
#
# emptyNet = True
#  i  30351
#  game_id 2020020502
# 273 event idx
#
# emptyNet = True
#  i  30924
#  game_id 2020020511
# 291 event idx
#
# emptyNet = True
#  i  30995
#  game_id 2020020512
# 306 event idx
#
# emptyNet = True
#  i  31426
#  game_id 2020020519
# 325 event idx
#
# emptyNet = True
#  i  31784
#  game_id 2020020525
# 247 event idx
#
# emptyNet = True
#  i  31785
#  game_id 2020020525
# 253 event idx
#
# emptyNet = True
#  i  32189
#  game_id 2020020532
# 332 event idx
#
# emptyNet = True
#  i  32658
#  game_id 2020020540
# 303 event idx
#
# emptyNet = True
#  i  32823
#  game_id 2020020543
# 308 event idx
#
# emptyNet = True
#  i  32869
#  game_id 2020020544
# 257 event idx
#
# emptyNet = True
#  i  32870
#  game_id 2020020544
# 259 event idx
#
# emptyNet = True
#  i  32963
#  game_id 2020020546
# 257 event idx
#
# emptyNet = True
#  i  33026
#  game_id 2020020547
# 312 event idx
#
# emptyNet = True
#  i  33185
#  game_id 2020020550
# 264 event idx
#
# emptyNet = True
#  i  33624
#  game_id 2020020557
# 254 event idx
#
# emptyNet = True
#  i  33689
#  game_id 2020020558
# 260 event idx
#
# emptyNet = True
#  i  33749
#  game_id 2020020559
# 257 event idx
#
# emptyNet = True
#  i  33871
#  game_id 2020020561
# 280 event idx
#
# emptyNet = True
#  i  34299
#  game_id 2020020568
# 298 event idx
#
# emptyNet = True
#  i  34434
#  game_id 2020020570
# 323 event idx
#
# emptyNet = True
#  i  34485
#  game_id 2020020571
# 324 event idx
#
# emptyNet = True
#  i  34855
#  game_id 2020020577
# 270 event idx
#
# emptyNet = True
#  i  35309
#  game_id 2020020584
# 274 event idx
#
# emptyNet = True
#  i  35364
#  game_id 2020020585
# 282 event idx
#
# emptyNet = True
#  i  35699
#  game_id 2020020590
# 341 event idx
#
# emptyNet = True
#  i  35829
#  game_id 2020020592
# 333 event idx
#
# emptyNet = True
#  i  36243
#  game_id 2020020599
# 230 event idx
#
# emptyNet = True
#  i  36928
#  game_id 2020020610
# 302 event idx
#
# emptyNet = True
#  i  36976
#  game_id 2020020611
# 240 event idx
#
# emptyNet = True
#  i  37182
#  game_id 2020020614
# 346 event idx
#
# emptyNet = True
#  i  37252
#  game_id 2020020615
# 347 event idx
#
# emptyNet = True
#  i  37254
#  game_id 2020020615
# 352 event idx
#
# emptyNet = True
#  i  37315
#  game_id 2020020616
# 276 event idx
#
# emptyNet = True
#  i  37439
#  game_id 2020020618
# 334 event idx
#
# emptyNet = True
#  i  37650
#  game_id 2020020621
# 310 event idx
#
# emptyNet = True
#  i  37889
#  game_id 2020020625
# 243 event idx
#
# emptyNet = True
#  i  38004
#  game_id 2020020627
# 279 event idx
#
# emptyNet = True
#  i  38115
#  game_id 2020020629
# 315 event idx
#
# emptyNet = True
#  i  38377
#  game_id 2020020633
# 322 event idx
#
# emptyNet = True
#  i  38566
#  game_id 2020020636
# 277 event idx
#
# emptyNet = True
#  i  38692
#  game_id 2020020638
# 302 event idx
#
# emptyNet = True
#  i  38755
#  game_id 2020020639
# 312 event idx
#
# emptyNet = True
#  i  38818
#  game_id 2020020640
# 287 event idx
#
# emptyNet = True
#  i  38881
#  game_id 2020020641
# 304 event idx
#
# emptyNet = True
#  i  39077
#  game_id 2020020644
# 295 event idx
#
# emptyNet = True
#  i  39190
#  game_id 2020020646
# 294 event idx
#
# emptyNet = True
#  i  39393
#  game_id 2020020650
# 273 event idx
#
# emptyNet = True
#  i  39525
#  game_id 2020020652
# 329 event idx
#
# emptyNet = True
#  i  39814
#  game_id 2020020657
# 312 event idx
#
# emptyNet = True
#  i  39976
#  game_id 2020020660
# 293 event idx
#
# emptyNet = True
#  i  40288
#  game_id 2020020665
# 331 event idx
#
# emptyNet = True
#  i  40335
#  game_id 2020020666
# 241 event idx
#
# emptyNet = True
#  i  40602
#  game_id 2020020671
# 333 event idx
#
# emptyNet = True
#  i  40956
#  game_id 2020020677
# 283 event idx
#
# emptyNet = True
#  i  41177
#  game_id 2020020681
# 235 event idx
#
# emptyNet = True
#  i  41235
#  game_id 2020020682
# 295 event idx
#
# emptyNet = True
#  i  41336
#  game_id 2020020684
# 244 event idx
#
# emptyNet = True
#  i  41337
#  game_id 2020020684
# 250 event idx
#
# emptyNet = True
#  i  41390
#  game_id 2020020685
# 298 event idx
#
# emptyNet = True
#  i  41734
#  game_id 2020020691
# 280 event idx
#
# emptyNet = True
#  i  41735
#  game_id 2020020691
# 290 event idx
#
# emptyNet = True
#  i  41801
#  game_id 2020020692
# 293 event idx
#
# emptyNet = True
#  i  41872
#  game_id 2020020693
# 357 event idx
#
# emptyNet = True
#  i  41940
#  game_id 2020020694
# 272 event idx
#
# emptyNet = True
#  i  41993
#  game_id 2020020695
# 249 event idx
#
# emptyNet = True
#  i  42331
#  game_id 2020020701
# 299 event idx
#
# shooter_count not equal to goalie_count
# i  42387
# game_id 2020020702
# 258 event idx
#
# score, not emptyNet, but no goalie! Add goalie as pd.NA
# emptyNet = True
#  i  42574
#  game_id 2020020705
# 294 event idx
#
# emptyNet = True
#  i  42712
#  game_id 2020020707
# 342 event idx
#
# emptyNet = True
#  i  42761
#  game_id 2020020708
# 264 event idx
#
# emptyNet = True
#  i  42819
#  game_id 2020020709
# 315 event idx
#
# emptyNet = True
#  i  42888
#  game_id 2020020710
# 300 event idx
#
# emptyNet = True
#  i  43001
#  game_id 2020020712
# 301 event idx
#
# emptyNet = True
#  i  43207
#  game_id 2020020715
# 289 event idx
#
# emptyNet = True
#  i  43267
#  game_id 2020020716
# 300 event idx
#
# emptyNet = True
#  i  43384
#  game_id 2020020718
# 305 event idx
#
# emptyNet = True
#  i  43613
#  game_id 2020020722
# 276 event idx
#
# emptyNet = True
#  i  43866
#  game_id 2020020726
# 291 event idx
#
# emptyNet = True
#  i  43929
#  game_id 2020020727
# 317 event idx
#
# emptyNet = True
#  i  44002
#  game_id 2020020728
# 351 event idx
#
# emptyNet = True
#  i  44182
#  game_id 2020020731
# 256 event idx
#
# emptyNet = True
#  i  44245
#  game_id 2020020732
# 339 event idx
#
# emptyNet = True
#  i  44366
#  game_id 2020020734
# 287 event idx
#
# emptyNet = True
#  i  44423
#  game_id 2020020735
# 270 event idx
#
# emptyNet = True
#  i  44475
#  game_id 2020020736
# 284 event idx
#
# emptyNet = True
#  i  44530
#  game_id 2020020737
# 302 event idx
#
# emptyNet = True
#  i  44604
#  game_id 2020020738
# 286 event idx
#
# emptyNet = True
#  i  44774
#  game_id 2020020741
# 268 event idx
#
# emptyNet = True
#  i  44900
#  game_id 2020020743
# 303 event idx
#
# emptyNet = True
#  i  45088
#  game_id 2020020746
# 308 event idx
#
# emptyNet = True
#  i  45215
#  game_id 2020020748
# 321 event idx
#
# emptyNet = True
#  i  45281
#  game_id 2020020749
# 290 event idx
#
# emptyNet = True
#  i  45344
#  game_id 2020020750
# 283 event idx
#
# emptyNet = True
#  i  45408
#  game_id 2020020751
# 285 event idx
#
# emptyNet = True
#  i  45530
#  game_id 2020020753
# 268 event idx
#
# emptyNet = True
#  i  45591
#  game_id 2020020754
# 280 event idx
#
# emptyNet = True
#  i  46217
#  game_id 2020020765
# 252 event idx
#
# emptyNet = True
#  i  46218
#  game_id 2020020765
# 254 event idx
#
# emptyNet = True
#  i  46277
#  game_id 2020020766
# 290 event idx
#
# shooter_count not equal to goalie_count
# i  46780
# game_id 2020020773
# 289 event idx
#
# score, not emptyNet, but no goalie! Add goalie as pd.NA
# emptyNet = True
#  i  46952
#  game_id 2020020776
# 280 event idx
#
# emptyNet = True
#  i  47013
#  game_id 2020020777
# 323 event idx
#
# emptyNet = True
#  i  47137
#  game_id 2020020779
# 313 event idx
#
# emptyNet = True
#  i  47250
#  game_id 2020020781
# 291 event idx
#
# emptyNet = True
#  i  47320
#  game_id 2020020782
# 312 event idx
#
# emptyNet = True
#  i  47362
#  game_id 2020020783
# 273 event idx
#
# emptyNet = True
#  i  47410
#  game_id 2020020784
# 269 event idx
#
# emptyNet = True
#  i  47829
#  game_id 2020020791
# 302 event idx
#
# emptyNet = True
#  i  47927
#  game_id 2020020793
# 231 event idx
#
# emptyNet = True
#  i  47982
#  game_id 2020020794
# 324 event idx
#
# emptyNet = True
#  i  48693
#  game_id 2020020806
# 301 event idx
#
# emptyNet = True
#  i  48751
#  game_id 2020020807
# 315 event idx
#
# emptyNet = True
#  i  48752
#  game_id 2020020807
# 321 event idx
#
# emptyNet = True
#  i  49072
#  game_id 2020020812
# 278 event idx
#
# emptyNet = True
#  i  49202
#  game_id 2020020814
# 288 event idx
#
# emptyNet = True
#  i  49280
#  game_id 2020020815
# 314 event idx
#
# emptyNet = True
#  i  49340
#  game_id 2020020816
# 313 event idx
#
# emptyNet = True
#  i  49462
#  game_id 2020020818
# 277 event idx
#
# emptyNet = True
#  i  49944
#  game_id 2020020826
# 312 event idx
#
# emptyNet = True
#  i  50005
#  game_id 2020020827
# 313 event idx
#
# emptyNet = True
#  i  50006
#  game_id 2020020827
# 321 event idx
#
# emptyNet = True
#  i  50063
#  game_id 2020020828
# 265 event idx
#
# emptyNet = True
#  i  50117
#  game_id 2020020829
# 283 event idx
#
# emptyNet = True
#  i  50173
#  game_id 2020020830
# 288 event idx
#
# emptyNet = True
#  i  50233
#  game_id 2020020831
# 271 event idx
#
# emptyNet = True
#  i  50525
#  game_id 2020020836
# 305 event idx
#
# emptyNet = True
#  i  50754
#  game_id 2020020840
# 268 event idx
#
# emptyNet = True
#  i  51051
#  game_id 2020020845
# 226 event idx
#
# emptyNet = True
#  i  51052
#  game_id 2020020845
# 233 event idx
#
# emptyNet = True
#  i  51521
#  game_id 2020020853
# 279 event idx
#
# emptyNet = True
#  i  52016
#  game_id 2020020861
# 264 event idx
#
# emptyNet = True
#  i  52118
#  game_id 2020020863
# 283 event idx
#
# emptyNet = True
#  i  52182
#  game_id 2020020864
# 271 event idx
#
# emptyNet = True
#  i  52279
#  game_id 2020020866
# 339 event idx
#
# emptyNet = True
#  i  53228
#  game_id 2020030131
# 383 event idx
#
# emptyNet = True
#  i  53292
#  game_id 2020030132
# 383 event idx
#
# emptyNet = True
#  i  53765
#  game_id 2020030142
# 362 event idx
#
# emptyNet = True
#  i  53988
#  game_id 2020030145
# 378 event idx
#
# emptyNet = True
#  i  54041
#  game_id 2020030146
# 282 event idx
#
# emptyNet = True
#  i  54114
#  game_id 2020030151
# 338 event idx
#
# emptyNet = True
#  i  54183
#  game_id 2020030152
# 297 event idx
#
# emptyNet = True
#  i  54184
#  game_id 2020030152
# 304 event idx
#
# emptyNet = True
#  i  54242
#  game_id 2020030153
# 317 event idx
#
# emptyNet = True
#  i  54295
#  game_id 2020030154
# 285 event idx
#
# emptyNet = True
#  i  54296
#  game_id 2020030154
# 289 event idx
#
# emptyNet = True
#  i  54487
#  game_id 2020030163
# 317 event idx
#
# emptyNet = True
#  i  54539
#  game_id 2020030164
# 288 event idx
#
# emptyNet = True
#  i  54593
#  game_id 2020030165
# 343 event idx
#
# emptyNet = True
#  i  54695
#  game_id 2020030167
# 379 event idx
#
# emptyNet = True
#  i  54818
#  game_id 2020030172
# 351 event idx
#
# emptyNet = True
#  i  54936
#  game_id 2020030174
# 324 event idx
#
# emptyNet = True
#  i  55127
#  game_id 2020030177
# 304 event idx
#
# emptyNet = True
#  i  55183
#  game_id 2020030181
# 359 event idx
#
# emptyNet = True
#  i  55184
#  game_id 2020030181
# 364 event idx
#
# emptyNet = True
#  i  55488
#  game_id 2020030211
# 342 event idx
#
# emptyNet = True
#  i  55701
#  game_id 2020030214
# 325 event idx
#
# emptyNet = True
#  i  55702
#  game_id 2020030214
# 331 event idx
#
# emptyNet = True
#  i  55816
#  game_id 2020030216
# 302 event idx
#
# emptyNet = True
#  i  55818
#  game_id 2020030216
# 306 event idx
#
# emptyNet = True
#  i  56454
#  game_id 2020030236
# 344 event idx
#
# emptyNet = True
#  i  56521
#  game_id 2020030241
# 307 event idx
#
# emptyNet = True
#  i  56631
#  game_id 2020030243
# 322 event idx
#
# emptyNet = True
#  i  56980
#  game_id 2020030315
# 328 event idx
#
# emptyNet = True
#  i  57624
#  game_id 2020030413
# 338 event idx
#
# 57734
# 57734
# 57734
# 57734
# 57734
# 57734
# 57734
# 57734
# 57734
# 57734
# 57734
# 57734

# %%
d2020
# Out:
#           game_id event_idx period periodTime             teamInfo isGoal  \
# 0      2020020001         4      1      00:16  Philadelphia Flyers  False
# 1      2020020001         7      1      00:34  Pittsburgh Penguins  False
# 2      2020020001        10      1      01:05  Philadelphia Flyers  False
# 3      2020020001        22      1      02:51  Pittsburgh Penguins  False
# 4      2020020001        27      1      03:44  Philadelphia Flyers  False
# ...           ...       ...    ...        ...                  ...    ...
# 57729  2020030415       335      3      16:19  Tampa Bay Lightning  False
# 57730  2020030415       338      3      17:13  Tampa Bay Lightning  False
# 57731  2020030415       345      3      19:01   Montréal Canadiens  False
# 57732  2020030415       346      3      19:10   Montréal Canadiens  False
# 57733  2020030415       347      3      19:24   Montréal Canadiens  False
#
#          shotType coordinates_x coordinates_y            shooter  \
# 0      Wrist Shot         -74.0          29.0     Travis Konecny
# 1      Wrist Shot          49.0         -25.0     Evan Rodrigues
# 2        Backhand         -52.0         -31.0       Joel Farabee
# 3       Snap Shot          43.0          39.0     Evan Rodrigues
# 4       Slap Shot         -53.0           8.0      Claude Giroux
# ...           ...           ...           ...                ...
# 57729  Wrist Shot          57.0          30.0      Blake Coleman
# 57730    Backhand          56.0         -31.0  Mikhail Sergachev
# 57731  Wrist Shot         -45.0         -14.0      Tyler Toffoli
# 57732    Backhand         -77.0          -3.0      Cole Caufield
# 57733  Wrist Shot         -77.0          18.0      Cole Caufield
#
#                    goalie emptyNet strength
# 0           Tristan Jarry    False       NA
# 1             Carter Hart    False       NA
# 2           Tristan Jarry    False       NA
# 3             Carter Hart    False       NA
# 4           Tristan Jarry    False       NA
# ...                   ...      ...      ...
# 57729         Carey Price    False       NA
# 57730         Carey Price    False       NA
# 57731  Andrei Vasilevskiy    False       NA
# 57732  Andrei Vasilevskiy    False       NA
# 57733  Andrei Vasilevskiy    False       NA
#
# [57734 rows x 13 columns]

# %%
a = np.array([1, 2, 3, np.NaN]).tolist()
a
# Out:
# [1.0, 2.0, 3.0, nan]

# %%
b = np.array([1, 2, 3, pd.NA]).tolist()
b
# Out:
# [1, 2, 3, <NA>]

# %%
pd.Series([1,2,3,pd.NA])[3]
# Out:
# pandas._libs.missing.NAType

# %%
d2

# %%
dfs.iloc[:,1]['result']

# %%
dfs["2019020001"][""]
# Out:
# (6,)

# %%
dfs.iloc[:,1270]
# Out:
# copyright    NHL and the NHL Shield are registered trademar...
# gamePk                                              2019021271
# link                         /api/v1/game/2019021271/feed/live
# metaData          {'wait': 10, 'timeStamp': '20200404_160017'}
# gameData     {'game': {'pk': 2019021271, 'season': '2019202...
# liveData     {'plays': {'allPlays': [], 'scoringPlays': [],...
# Name: 2019021271, dtype: object

# %%
dfs.iloc[:,1271]
# Out:
# copyright    NHL and the NHL Shield are registered trademar...
# gamePk                                              2019030001
# link                         /api/v1/game/2019030001/feed/live
# metaData          {'wait': 10, 'timeStamp': '20200806_222251'}
# gameData     {'game': {'pk': 2019030001, 'season': '2019202...
# liveData     {'plays': {'allPlays': [{'result': {'event': '...
# Name: 2019030001, dtype: object

# %%
dfs.iloc[:,5].name
# Out:
# '2019020006'

# %%
dfs.iloc[5,:] # row is different dictionary
# column is match
# Out:
# 2019020001    {'plays': {'allPlays': [{'result': {'event': '...
# 2019020002    {'plays': {'allPlays': [{'result': {'event': '...
# 2019020003    {'plays': {'allPlays': [{'result': {'event': '...
# 2019020004    {'plays': {'allPlays': [{'result': {'event': '...
# 2019020005    {'plays': {'allPlays': [{'result': {'event': '...
#                                     ...
# 2019030413    {'plays': {'allPlays': [{'result': {'event': '...
# 2019030414    {'plays': {'allPlays': [{'result': {'event': '...
# 2019030415    {'plays': {'allPlays': [{'result': {'event': '...
# 2019030416    {'plays': {'allPlays': [{'result': {'event': '...
# 2019030417    {'plays': {'allPlays': [], 'scoringPlays': [],...
# Name: liveData, Length: 1428, dtype: object

# %%
dfs.iloc[:,1]['liveData']['plays']['allPlays'][1]
# Out:
# {'result': {'event': 'Period Ready',
#   'eventCode': 'STL52',
#   'eventTypeId': 'PERIOD_READY',
#   'description': 'Period Ready'},
#  'about': {'eventIdx': 1,
#   'eventId': 52,
#   'period': 1,
#   'periodType': 'REGULAR',
#   'ordinalNum': '1st',
#   'periodTime': '00:00',
#   'periodTimeRemaining': '20:00',
#   'dateTime': '2019-10-03T00:19:22Z',
#   'goals': {'away': 0, 'home': 0}},
#  'coordinates': {}}

# %%
dfs.shape[1]
# Out:
# 1428

# %%
print(len(emptyNet))
print(len(game_id))
print(len(goalie))
# Out:
# 303
# 303
# 303

# %%
df2
# Out:
#         game_id event_idx period periodTime             teamInfo isGoal  \
# 0    2019020001         4      1      00:25      Ottawa Senators   True
# 1    2019020001        12      1      01:31  Toronto Maple Leafs  False
# 2    2019020001        19      1      03:23      Ottawa Senators  False
# 3    2019020001        22      1      03:56  Toronto Maple Leafs  False
# 4    2019020001        27      1      04:47  Toronto Maple Leafs  False
# ..          ...       ...    ...        ...                  ...    ...
# 298  2019020005       260      3      13:31  Tampa Bay Lightning  False
# 299  2019020005       262      3      13:49  Tampa Bay Lightning  False
# 300  2019020005       264      3      13:51  Tampa Bay Lightning   True
# 301  2019020005       267      3      14:43  Tampa Bay Lightning  False
# 302  2019020005       283      3      19:14  Tampa Bay Lightning   True
#
#        shotType coordinates_x coordinates_y         shooter  \
# 0        Tip-In          85.0          -1.0   Brady Tkachuk
# 1     Snap Shot         -32.0          -2.0   Morgan Rielly
# 2     Snap Shot          63.0          -6.0    Dylan DeMelo
# 3    Wrist Shot         -59.0         -20.0   Morgan Rielly
# 4     Slap Shot         -42.0         -29.0    Tyson Barrie
# ..          ...           ...           ...             ...
# 298   Slap Shot          62.0          33.0  Steven Stamkos
# 299    Backhand          80.0           8.0   Tyler Johnson
# 300  Wrist Shot          85.0           5.0      Pat Maroon
# 301      Tip-In          70.0           1.0    Yanni Gourde
# 302  Wrist Shot         -36.0         -37.0     Erik Cernak
#
#                 goalie emptyNet
# 0    Frederik Andersen    False
# 1       Craig Anderson    False
# 2    Frederik Andersen    False
# 3       Craig Anderson    False
# 4       Craig Anderson    False
# ..                 ...      ...
# 298   Sergei Bobrovsky    False
# 299   Sergei Bobrovsky    False
# 300   Sergei Bobrovsky    False
# 301   Sergei Bobrovsky    False
# 302           EmptyNet     True
#
# [303 rows x 12 columns]

# %%
df['result'][381]
# Out:
# {'event': 'Goal',
#  'eventCode': 'NYR851',
#  'eventTypeId': 'GOAL',
#  'description': 'Brendan Smith (1) Wrist Shot, assists: Mika Zibanejad (3)',
#  'secondaryType': 'Wrist Shot',
#  'strength': {'code': 'SHG', 'name': 'Short Handed'},
#  'gameWinningGoal': False,
#  'emptyNet': True}

# %%
'emptyNet' in df['result'][531]
# Out:
# False

# %%
'emptyNet' in df['result'][0]
# Out:
# True

# %%
df['about'][531]
# Out:
# {'eventIdx': 377,
#  'eventId': 856,
#  'period': 5,
#  'periodType': 'SHOOTOUT',
#  'ordinalNum': 'SO',
#  'periodTime': '00:00',
#  'periodTimeRemaining': '00:00',
#  'dateTime': '2019-10-04T01:53:04Z',
#  'goals': {'away': 3, 'home': 3}}

# %%
df['result'][0]['emptyNet']
# Out:
# False

# %%
df
# Out:
#                                                 players  \
# 0     [{'player': {'id': 8480801, 'fullName': 'Brady...
# 1     [{'player': {'id': 8476853, 'fullName': 'Morga...
# 2     [{'player': {'id': 8476331, 'fullName': 'Dylan...
# 3     [{'player': {'id': 8476853, 'fullName': 'Morga...
# 4     [{'player': {'id': 8475197, 'fullName': 'Tyson...
# ...                                                 ...
# 3188  [{'player': {'id': 8475208, 'fullName': 'Brian...
# 3189  [{'player': {'id': 8474683, 'fullName': 'Derek...
# 3190  [{'player': {'id': 8480806, 'fullName': 'Isac ...
# 3191  [{'player': {'id': 8476312, 'fullName': 'Josh ...
# 3192  [{'player': {'id': 8479944, 'fullName': 'Zach ...
#
#                                                  result  \
# 0     {'event': 'Goal', 'eventCode': 'TOR10', 'event...
# 1     {'event': 'Shot', 'eventCode': 'TOR15', 'event...
# 2     {'event': 'Shot', 'eventCode': 'TOR20', 'event...
# 3     {'event': 'Shot', 'eventCode': 'TOR21', 'event...
# 4     {'event': 'Shot', 'eventCode': 'TOR24', 'event...
# ...                                                 ...
# 3188  {'event': 'Shot', 'eventCode': 'PIT596', 'even...
# 3189  {'event': 'Shot', 'eventCode': 'PIT599', 'even...
# 3190  {'event': 'Shot', 'eventCode': 'PIT803', 'even...
# 3191  {'event': 'Shot', 'eventCode': 'PIT802', 'even...
# 3192  {'event': 'Shot', 'eventCode': 'PIT805', 'even...
#
#                                                   about  \
# 0     {'eventIdx': 4, 'eventId': 10, 'period': 1, 'p...
# 1     {'eventIdx': 12, 'eventId': 15, 'period': 1, '...
# 2     {'eventIdx': 19, 'eventId': 20, 'period': 1, '...
# 3     {'eventIdx': 22, 'eventId': 21, 'period': 1, '...
# 4     {'eventIdx': 27, 'eventId': 24, 'period': 1, '...
# ...                                                 ...
# 3188  {'eventIdx': 308, 'eventId': 596, 'period': 3,...
# 3189  {'eventIdx': 312, 'eventId': 599, 'period': 3,...
# 3190  {'eventIdx': 322, 'eventId': 803, 'period': 3,...
# 3191  {'eventIdx': 323, 'eventId': 802, 'period': 3,...
# 3192  {'eventIdx': 327, 'eventId': 805, 'period': 3,...
#
#                    coordinates  \
# 0       {'x': 85.0, 'y': -1.0}
# 1      {'x': -32.0, 'y': -2.0}
# 2       {'x': 63.0, 'y': -6.0}
# 3     {'x': -59.0, 'y': -20.0}
# 4     {'x': -42.0, 'y': -29.0}
# ...                        ...
# 3188    {'x': 36.0, 'y': 38.0}
# 3189  {'x': -87.0, 'y': -21.0}
# 3190   {'x': -76.0, 'y': 14.0}
# 3191   {'x': -42.0, 'y': 12.0}
# 3192     {'x': 80.0, 'y': 6.0}
#
#                                                    team
# 0     {'id': 9, 'name': 'Ottawa Senators', 'link': '...
# 1     {'id': 10, 'name': 'Toronto Maple Leafs', 'lin...
# 2     {'id': 9, 'name': 'Ottawa Senators', 'link': '...
# 3     {'id': 10, 'name': 'Toronto Maple Leafs', 'lin...
# 4     {'id': 10, 'name': 'Toronto Maple Leafs', 'lin...
# ...                                                 ...
# 3188  {'id': 5, 'name': 'Pittsburgh Penguins', 'link...
# 3189  {'id': 24, 'name': 'Anaheim Ducks', 'link': '/...
# 3190  {'id': 24, 'name': 'Anaheim Ducks', 'link': '/...
# 3191  {'id': 24, 'name': 'Anaheim Ducks', 'link': '/...
# 3192  {'id': 5, 'name': 'Pittsburgh Penguins', 'link...
#
# [3193 rows x 5 columns]

# %%
df['result'][531]
# Out:
# {'event': 'Goal',
#  'eventCode': 'CAR856',
#  'eventTypeId': 'GOAL',
#  'description': 'Dougie Hamilton - Wrist Shot',
#  'secondaryType': 'Wrist Shot',
#  'strength': {'code': 'EVEN', 'name': 'Even'},
#  'gameWinningGoal': False}

# %%
df2
# Out:
#        game_id event_idx period periodTime             teamInfo isGoal  \
# 0   2019020001         4      1      00:25      Ottawa Senators   True
# 1   2019020001        12      1      01:31  Toronto Maple Leafs  False
# 2   2019020001        19      1      03:23      Ottawa Senators  False
# 3   2019020001        22      1      03:56  Toronto Maple Leafs  False
# 4   2019020001        27      1      04:47  Toronto Maple Leafs  False
# ..         ...       ...    ...        ...                  ...    ...
# 63  2019020001       361      3      17:45      Ottawa Senators  False
# 64  2019020001       362      3      17:45      Ottawa Senators   True
# 65  2019020001       368      3      18:22      Ottawa Senators  False
# 66  2019020001       369      3      18:44      Ottawa Senators  False
# 67  2019020001       376      3      19:37      Ottawa Senators  False
#
#       shotType coordinates_x coordinates_y          shooter  \
# 0       Tip-In          85.0          -1.0    Brady Tkachuk
# 1    Snap Shot         -32.0          -2.0    Morgan Rielly
# 2    Snap Shot          63.0          -6.0     Dylan DeMelo
# 3   Wrist Shot         -59.0         -20.0    Morgan Rielly
# 4    Slap Shot         -42.0         -29.0     Tyson Barrie
# ..         ...           ...           ...              ...
# 63  Wrist Shot          85.0          30.0    Chris Tierney
# 64  Wrist Shot          72.0           2.0       Bobby Ryan
# 65   Slap Shot          38.0         -24.0    Thomas Chabot
# 66  Wrist Shot          64.0          28.0  Anthony Duclair
# 67  Wrist Shot          48.0          28.0    Thomas Chabot
#
#                goalie emptyNet
# 0   Frederik Andersen    false
# 1      Craig Anderson       NA
# 2   Frederik Andersen       NA
# 3      Craig Anderson       NA
# 4      Craig Anderson       NA
# ..                ...      ...
# 63  Frederik Andersen       NA
# 64  Frederik Andersen    false
# 65  Frederik Andersen       NA
# 66  Frederik Andersen       NA
# 67  Frederik Andersen       NA
#
# [68 rows x 12 columns]

# %%
rows_list
# Out:
# [{'players': [{'player': {'id': 8480801,
#      'fullName': 'Brady Tkachuk',
#      'link': '/api/v1/people/8480801'},
#     'playerType': 'Scorer',
#     'seasonTotal': 1},
#    {'player': {'id': 8477015,
#      'fullName': 'Connor Brown',
#      'link': '/api/v1/people/8477015'},
#     'playerType': 'Assist',
#     'seasonTotal': 1},
#    {'player': {'id': 8478400,
#      'fullName': 'Colin White',
#      'link': '/api/v1/people/8478400'},
#     'playerType': 'Assist',
#     'seasonTotal': 1},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Goal',
#    'eventCode': 'TOR10',
#    'eventTypeId': 'GOAL',
#    'description': 'Brady Tkachuk (1) Tip-In, assists: Connor Brown (1), Colin White (1)',
#    'secondaryType': 'Tip-In',
#    'strength': {'code': 'EVEN', 'name': 'Even'},
#    'gameWinningGoal': False,
#    'emptyNet': False},
#   'about': {'eventIdx': 4,
#    'eventId': 10,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '00:25',
#    'periodTimeRemaining': '19:35',
#    'dateTime': '2019-10-02T23:15:32Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': 85.0, 'y': -1.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8476853,
#      'fullName': 'Morgan Rielly',
#      'link': '/api/v1/people/8476853'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR15',
#    'eventTypeId': 'SHOT',
#    'description': 'Morgan Rielly Snap Shot saved by Craig Anderson',
#    'secondaryType': 'Snap Shot'},
#   'about': {'eventIdx': 12,
#    'eventId': 15,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '01:31',
#    'periodTimeRemaining': '18:29',
#    'dateTime': '2019-10-02T23:18:23Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -32.0, 'y': -2.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8476331,
#      'fullName': 'Dylan DeMelo',
#      'link': '/api/v1/people/8476331'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR20',
#    'eventTypeId': 'SHOT',
#    'description': 'Dylan DeMelo Snap Shot saved by Frederik Andersen',
#    'secondaryType': 'Snap Shot'},
#   'about': {'eventIdx': 19,
#    'eventId': 20,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '03:23',
#    'periodTimeRemaining': '16:37',
#    'dateTime': '2019-10-02T23:20:45Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': 63.0, 'y': -6.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8476853,
#      'fullName': 'Morgan Rielly',
#      'link': '/api/v1/people/8476853'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR21',
#    'eventTypeId': 'SHOT',
#    'description': 'Morgan Rielly Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 22,
#    'eventId': 21,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '03:56',
#    'periodTimeRemaining': '16:04',
#    'dateTime': '2019-10-02T23:21:17Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -59.0, 'y': -20.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8475197,
#      'fullName': 'Tyson Barrie',
#      'link': '/api/v1/people/8475197'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR24',
#    'eventTypeId': 'SHOT',
#    'description': 'Tyson Barrie Slap Shot saved by Craig Anderson',
#    'secondaryType': 'Slap Shot'},
#   'about': {'eventIdx': 27,
#    'eventId': 24,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '04:47',
#    'periodTimeRemaining': '15:13',
#    'dateTime': '2019-10-02T23:22:36Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -42.0, 'y': -29.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8475197,
#      'fullName': 'Tyson Barrie',
#      'link': '/api/v1/people/8475197'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR25',
#    'eventTypeId': 'SHOT',
#    'description': 'Tyson Barrie Slap Shot saved by Craig Anderson',
#    'secondaryType': 'Slap Shot'},
#   'about': {'eventIdx': 28,
#    'eventId': 25,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '04:53',
#    'periodTimeRemaining': '15:07',
#    'dateTime': '2019-10-02T23:22:41Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -52.0, 'y': -7.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8476879,
#      'fullName': 'Cody Ceci',
#      'link': '/api/v1/people/8476879'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR28',
#    'eventTypeId': 'SHOT',
#    'description': 'Cody Ceci Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 30,
#    'eventId': 28,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '05:31',
#    'periodTimeRemaining': '14:29',
#    'dateTime': '2019-10-02T23:23:19Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -38.0, 'y': 38.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8477341,
#      'fullName': 'Andreas Johnsson',
#      'link': '/api/v1/people/8477341'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR29',
#    'eventTypeId': 'SHOT',
#    'description': 'Andreas Johnsson Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 32,
#    'eventId': 29,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '05:52',
#    'periodTimeRemaining': '14:08',
#    'dateTime': '2019-10-02T23:23:40Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -76.0, 'y': -14.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8478483,
#      'fullName': 'Mitchell Marner',
#      'link': '/api/v1/people/8478483'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR31',
#    'eventTypeId': 'SHOT',
#    'description': 'Mitchell Marner Slap Shot saved by Craig Anderson',
#    'secondaryType': 'Slap Shot'},
#   'about': {'eventIdx': 36,
#    'eventId': 31,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '06:02',
#    'periodTimeRemaining': '13:58',
#    'dateTime': '2019-10-02T23:24:37Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -63.0, 'y': -31.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8477939,
#      'fullName': 'William Nylander',
#      'link': '/api/v1/people/8477939'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR37',
#    'eventTypeId': 'SHOT',
#    'description': 'William Nylander Tip-In saved by Craig Anderson',
#    'secondaryType': 'Tip-In'},
#   'about': {'eventIdx': 42,
#    'eventId': 37,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '07:11',
#    'periodTimeRemaining': '12:49',
#    'dateTime': '2019-10-02T23:26:14Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -78.0, 'y': 13.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8475197,
#      'fullName': 'Tyson Barrie',
#      'link': '/api/v1/people/8475197'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR38',
#    'eventTypeId': 'SHOT',
#    'description': 'Tyson Barrie Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 43,
#    'eventId': 38,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '07:30',
#    'periodTimeRemaining': '12:30',
#    'dateTime': '2019-10-02T23:26:33Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -32.0, 'y': 34.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8477939,
#      'fullName': 'William Nylander',
#      'link': '/api/v1/people/8477939'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR39',
#    'eventTypeId': 'SHOT',
#    'description': 'William Nylander Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 44,
#    'eventId': 39,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '07:39',
#    'periodTimeRemaining': '12:21',
#    'dateTime': '2019-10-02T23:26:42Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -80.0, 'y': -4.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8478400,
#      'fullName': 'Colin White',
#      'link': '/api/v1/people/8478400'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR42',
#    'eventTypeId': 'SHOT',
#    'description': 'Colin White Snap Shot saved by Frederik Andersen',
#    'secondaryType': 'Snap Shot'},
#   'about': {'eventIdx': 47,
#    'eventId': 42,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '07:59',
#    'periodTimeRemaining': '12:01',
#    'dateTime': '2019-10-02T23:27:45Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': 78.0, 'y': -5.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8478469,
#      'fullName': 'Thomas Chabot',
#      'link': '/api/v1/people/8478469'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR43',
#    'eventTypeId': 'SHOT',
#    'description': 'Thomas Chabot Snap Shot saved by Frederik Andersen',
#    'secondaryType': 'Snap Shot'},
#   'about': {'eventIdx': 48,
#    'eventId': 43,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '08:05',
#    'periodTimeRemaining': '11:55',
#    'dateTime': '2019-10-02T23:27:52Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': 47.0, 'y': 23.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8479318,
#      'fullName': 'Auston Matthews',
#      'link': '/api/v1/people/8479318'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR45',
#    'eventTypeId': 'SHOT',
#    'description': 'Auston Matthews Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 52,
#    'eventId': 45,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '08:15',
#    'periodTimeRemaining': '11:45',
#    'dateTime': '2019-10-02T23:30:47Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -64.0, 'y': 24.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8477407,
#      'fullName': 'Anthony Duclair',
#      'link': '/api/v1/people/8477407'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR47',
#    'eventTypeId': 'SHOT',
#    'description': 'Anthony Duclair Backhand saved by Frederik Andersen',
#    'secondaryType': 'Backhand'},
#   'about': {'eventIdx': 55,
#    'eventId': 47,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '09:08',
#    'periodTimeRemaining': '10:52',
#    'dateTime': '2019-10-02T23:31:40Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': 83.0, 'y': -4.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8474589,
#      'fullName': 'Tyler Ennis',
#      'link': '/api/v1/people/8474589'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR49',
#    'eventTypeId': 'SHOT',
#    'description': 'Tyler Ennis Snap Shot saved by Frederik Andersen',
#    'secondaryType': 'Snap Shot'},
#   'about': {'eventIdx': 57,
#    'eventId': 49,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '10:06',
#    'periodTimeRemaining': '09:54',
#    'dateTime': '2019-10-02T23:32:38Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': 67.0, 'y': -20.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8479458,
#      'fullName': 'Nikita Zaitsev',
#      'link': '/api/v1/people/8479458'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR202',
#    'eventTypeId': 'SHOT',
#    'description': 'Nikita Zaitsev Slap Shot saved by Frederik Andersen',
#    'secondaryType': 'Slap Shot'},
#   'about': {'eventIdx': 60,
#    'eventId': 202,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '10:12',
#    'periodTimeRemaining': '09:48',
#    'dateTime': '2019-10-02T23:35:15Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': 47.0, 'y': -36.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8477407,
#      'fullName': 'Anthony Duclair',
#      'link': '/api/v1/people/8477407'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR206',
#    'eventTypeId': 'SHOT',
#    'description': 'Anthony Duclair Wrist Shot saved by Frederik Andersen',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 69,
#    'eventId': 206,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '12:22',
#    'periodTimeRemaining': '07:38',
#    'dateTime': '2019-10-02T23:38:00Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': 56.0, 'y': 28.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8476853,
#      'fullName': 'Morgan Rielly',
#      'link': '/api/v1/people/8476853'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR209',
#    'eventTypeId': 'SHOT',
#    'description': 'Morgan Rielly Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 73,
#    'eventId': 209,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '12:58',
#    'periodTimeRemaining': '07:02',
#    'dateTime': '2019-10-02T23:39:07Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -45.0, 'y': -41.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8480801,
#      'fullName': 'Brady Tkachuk',
#      'link': '/api/v1/people/8480801'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR210',
#    'eventTypeId': 'SHOT',
#    'description': 'Brady Tkachuk Wrist Shot saved by Frederik Andersen',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 75,
#    'eventId': 210,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '13:27',
#    'periodTimeRemaining': '06:33',
#    'dateTime': '2019-10-02T23:39:30Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': 50.0, 'y': 22.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8476853,
#      'fullName': 'Morgan Rielly',
#      'link': '/api/v1/people/8476853'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR219',
#    'eventTypeId': 'SHOT',
#    'description': 'Morgan Rielly Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 91,
#    'eventId': 219,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '15:49',
#    'periodTimeRemaining': '04:11',
#    'dateTime': '2019-10-02T23:43:27Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -41.0, 'y': -34.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8475166,
#      'fullName': 'John Tavares',
#      'link': '/api/v1/people/8475166'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR221',
#    'eventTypeId': 'SHOT',
#    'description': 'John Tavares Snap Shot saved by Craig Anderson',
#    'secondaryType': 'Snap Shot'},
#   'about': {'eventIdx': 94,
#    'eventId': 221,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '16:11',
#    'periodTimeRemaining': '03:49',
#    'dateTime': '2019-10-02T23:46:25Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -62.0, 'y': -19.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8479458,
#      'fullName': 'Nikita Zaitsev',
#      'link': '/api/v1/people/8479458'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR227',
#    'eventTypeId': 'SHOT',
#    'description': 'Nikita Zaitsev Snap Shot saved by Frederik Andersen',
#    'secondaryType': 'Snap Shot'},
#   'about': {'eventIdx': 109,
#    'eventId': 227,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '18:38',
#    'periodTimeRemaining': '01:22',
#    'dateTime': '2019-10-02T23:49:48Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': 67.0, 'y': -36.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8480073,
#      'fullName': 'Erik Brannstrom',
#      'link': '/api/v1/people/8480073'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR229',
#    'eventTypeId': 'SHOT',
#    'description': 'Erik Brannstrom Wrist Shot saved by Frederik Andersen',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 112,
#    'eventId': 229,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '18:46',
#    'periodTimeRemaining': '01:14',
#    'dateTime': '2019-10-02T23:50:25Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': 43.0, 'y': 32.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8471676,
#      'fullName': 'Bobby Ryan',
#      'link': '/api/v1/people/8471676'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR232',
#    'eventTypeId': 'SHOT',
#    'description': 'Bobby Ryan Wrist Shot saved by Frederik Andersen',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 119,
#    'eventId': 232,
#    'period': 1,
#    'periodType': 'REGULAR',
#    'ordinalNum': '1st',
#    'periodTime': '19:37',
#    'periodTimeRemaining': '00:23',
#    'dateTime': '2019-10-02T23:51:48Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': 30.0, 'y': -16.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8477939,
#      'fullName': 'William Nylander',
#      'link': '/api/v1/people/8477939'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR246',
#    'eventTypeId': 'SHOT',
#    'description': 'William Nylander Backhand saved by Craig Anderson',
#    'secondaryType': 'Backhand'},
#   'about': {'eventIdx': 131,
#    'eventId': 246,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '01:06',
#    'periodTimeRemaining': '18:54',
#    'dateTime': '2019-10-03T00:12:13Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': 81.0, 'y': -1.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8479458,
#      'fullName': 'Nikita Zaitsev',
#      'link': '/api/v1/people/8479458'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR249',
#    'eventTypeId': 'SHOT',
#    'description': 'Nikita Zaitsev Wrist Shot saved by Frederik Andersen',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 137,
#    'eventId': 249,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '01:41',
#    'periodTimeRemaining': '18:19',
#    'dateTime': '2019-10-03T00:13:49Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': -31.0, 'y': 30.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8475197,
#      'fullName': 'Tyson Barrie',
#      'link': '/api/v1/people/8475197'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR453',
#    'eventTypeId': 'SHOT',
#    'description': 'Tyson Barrie Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 144,
#    'eventId': 453,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '02:20',
#    'periodTimeRemaining': '17:40',
#    'dateTime': '2019-10-03T00:15:27Z',
#    'goals': {'away': 1, 'home': 0}},
#   'coordinates': {'x': 56.0, 'y': -23.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8477512,
#      'fullName': 'Frederik Gauthier',
#      'link': '/api/v1/people/8477512'},
#     'playerType': 'Scorer',
#     'seasonTotal': 1},
#    {'player': {'id': 8475197,
#      'fullName': 'Tyson Barrie',
#      'link': '/api/v1/people/8475197'},
#     'playerType': 'Assist',
#     'seasonTotal': 1},
#    {'player': {'id': 8478857,
#      'fullName': 'Dmytro Timashov',
#      'link': '/api/v1/people/8478857'},
#     'playerType': 'Assist',
#     'seasonTotal': 1},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Goal',
#    'eventCode': 'TOR454',
#    'eventTypeId': 'GOAL',
#    'description': 'Frederik Gauthier (1) Wrist Shot, assists: Tyson Barrie (1), Dmytro Timashov (1)',
#    'secondaryType': 'Wrist Shot',
#    'strength': {'code': 'EVEN', 'name': 'Even'},
#    'gameWinningGoal': False,
#    'emptyNet': False},
#   'about': {'eventIdx': 145,
#    'eventId': 454,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '02:20',
#    'periodTimeRemaining': '17:40',
#    'dateTime': '2019-10-03T00:15:36Z',
#    'goals': {'away': 1, 'home': 1}},
#   'coordinates': {'x': 86.0, 'y': 0.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8480873,
#      'fullName': 'Rasmus Sandin',
#      'link': '/api/v1/people/8480873'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR456',
#    'eventTypeId': 'SHOT',
#    'description': 'Rasmus Sandin Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 149,
#    'eventId': 456,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '02:46',
#    'periodTimeRemaining': '17:14',
#    'dateTime': '2019-10-03T00:16:44Z',
#    'goals': {'away': 1, 'home': 1}},
#   'coordinates': {'x': 43.0, 'y': 9.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8475197,
#      'fullName': 'Tyson Barrie',
#      'link': '/api/v1/people/8475197'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR463',
#    'eventTypeId': 'SHOT',
#    'description': 'Tyson Barrie Slap Shot saved by Craig Anderson',
#    'secondaryType': 'Slap Shot'},
#   'about': {'eventIdx': 160,
#    'eventId': 463,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '04:33',
#    'periodTimeRemaining': '15:27',
#    'dateTime': '2019-10-03T00:19:32Z',
#    'goals': {'away': 1, 'home': 1}},
#   'coordinates': {'x': 37.0, 'y': -31.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8475716,
#      'fullName': 'Martin Marincin',
#      'link': '/api/v1/people/8475716'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR465',
#    'eventTypeId': 'SHOT',
#    'description': 'Martin Marincin Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 163,
#    'eventId': 465,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '04:37',
#    'periodTimeRemaining': '15:23',
#    'dateTime': '2019-10-03T00:20:11Z',
#    'goals': {'away': 1, 'home': 1}},
#   'coordinates': {'x': 35.0, 'y': -38.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8480873,
#      'fullName': 'Rasmus Sandin',
#      'link': '/api/v1/people/8480873'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR466',
#    'eventTypeId': 'SHOT',
#    'description': 'Rasmus Sandin Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 164,
#    'eventId': 466,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '04:42',
#    'periodTimeRemaining': '15:18',
#    'dateTime': '2019-10-03T00:20:17Z',
#    'goals': {'away': 1, 'home': 1}},
#   'coordinates': {'x': 45.0, 'y': 21.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8479675,
#      'fullName': 'Trevor Moore',
#      'link': '/api/v1/people/8479675'},
#     'playerType': 'Scorer',
#     'seasonTotal': 1},
#    {'player': {'id': 8481624,
#      'fullName': 'Ilya Mikheyev',
#      'link': '/api/v1/people/8481624'},
#     'playerType': 'Assist',
#     'seasonTotal': 1},
#    {'player': {'id': 8480873,
#      'fullName': 'Rasmus Sandin',
#      'link': '/api/v1/people/8480873'},
#     'playerType': 'Assist',
#     'seasonTotal': 1},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Goal',
#    'eventCode': 'TOR467',
#    'eventTypeId': 'GOAL',
#    'description': 'Trevor Moore (1) Slap Shot, assists: Ilya Mikheyev (1), Rasmus Sandin (1)',
#    'secondaryType': 'Slap Shot',
#    'strength': {'code': 'EVEN', 'name': 'Even'},
#    'gameWinningGoal': False,
#    'emptyNet': False},
#   'about': {'eventIdx': 165,
#    'eventId': 467,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '04:42',
#    'periodTimeRemaining': '15:18',
#    'dateTime': '2019-10-03T00:20:25Z',
#    'goals': {'away': 1, 'home': 2}},
#   'coordinates': {'x': 84.0, 'y': 2.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8477149,
#      'fullName': 'Scott Sabourin',
#      'link': '/api/v1/people/8477149'},
#     'playerType': 'Scorer',
#     'seasonTotal': 1},
#    {'player': {'id': 8478488,
#      'fullName': 'Filip Chlapik',
#      'link': '/api/v1/people/8478488'},
#     'playerType': 'Assist',
#     'seasonTotal': 1},
#    {'player': {'id': 8476419,
#      'fullName': 'Jean-Gabriel Pageau',
#      'link': '/api/v1/people/8476419'},
#     'playerType': 'Assist',
#     'seasonTotal': 1},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Goal',
#    'eventCode': 'TOR472',
#    'eventTypeId': 'GOAL',
#    'description': 'Scott Sabourin (1) Wrist Shot, assists: Filip Chlapik (1), Jean-Gabriel Pageau (1)',
#    'secondaryType': 'Wrist Shot',
#    'strength': {'code': 'EVEN', 'name': 'Even'},
#    'gameWinningGoal': False,
#    'emptyNet': False},
#   'about': {'eventIdx': 172,
#    'eventId': 472,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '05:51',
#    'periodTimeRemaining': '14:09',
#    'dateTime': '2019-10-03T00:22:12Z',
#    'goals': {'away': 2, 'home': 2}},
#   'coordinates': {'x': -83.0, 'y': -6.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8476853,
#      'fullName': 'Morgan Rielly',
#      'link': '/api/v1/people/8476853'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR475',
#    'eventTypeId': 'SHOT',
#    'description': 'Morgan Rielly Backhand saved by Craig Anderson',
#    'secondaryType': 'Backhand'},
#   'about': {'eventIdx': 174,
#    'eventId': 475,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '06:01',
#    'periodTimeRemaining': '13:59',
#    'dateTime': '2019-10-03T00:23:12Z',
#    'goals': {'away': 2, 'home': 2}},
#   'coordinates': {'x': 12.0, 'y': -10.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8479318,
#      'fullName': 'Auston Matthews',
#      'link': '/api/v1/people/8479318'},
#     'playerType': 'Scorer',
#     'seasonTotal': 1},
#    {'player': {'id': 8477939,
#      'fullName': 'William Nylander',
#      'link': '/api/v1/people/8477939'},
#     'playerType': 'Assist',
#     'seasonTotal': 1},
#    {'player': {'id': 8476853,
#      'fullName': 'Morgan Rielly',
#      'link': '/api/v1/people/8476853'},
#     'playerType': 'Assist',
#     'seasonTotal': 1},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Goal',
#    'eventCode': 'TOR480',
#    'eventTypeId': 'GOAL',
#    'description': 'Auston Matthews (1) Wrist Shot, assists: William Nylander (1), Morgan Rielly (1)',
#    'secondaryType': 'Wrist Shot',
#    'strength': {'code': 'EVEN', 'name': 'Even'},
#    'gameWinningGoal': False,
#    'emptyNet': False},
#   'about': {'eventIdx': 181,
#    'eventId': 480,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '08:02',
#    'periodTimeRemaining': '11:58',
#    'dateTime': '2019-10-03T00:27:35Z',
#    'goals': {'away': 2, 'home': 3}},
#   'coordinates': {'x': 83.0, 'y': 5.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8471676,
#      'fullName': 'Bobby Ryan',
#      'link': '/api/v1/people/8471676'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR497',
#    'eventTypeId': 'SHOT',
#    'description': 'Bobby Ryan Wrist Shot saved by Frederik Andersen',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 210,
#    'eventId': 497,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '13:06',
#    'periodTimeRemaining': '06:54',
#    'dateTime': '2019-10-03T00:40:11Z',
#    'goals': {'away': 2, 'home': 3}},
#   'coordinates': {'x': -60.0, 'y': -24.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8475166,
#      'fullName': 'John Tavares',
#      'link': '/api/v1/people/8475166'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR601',
#    'eventTypeId': 'SHOT',
#    'description': 'John Tavares Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 216,
#    'eventId': 601,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '13:26',
#    'periodTimeRemaining': '06:34',
#    'dateTime': '2019-10-03T00:40:59Z',
#    'goals': {'away': 2, 'home': 3}},
#   'coordinates': {'x': 58.0, 'y': 17.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8479318,
#      'fullName': 'Auston Matthews',
#      'link': '/api/v1/people/8479318'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR608',
#    'eventTypeId': 'SHOT',
#    'description': 'Auston Matthews Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 229,
#    'eventId': 608,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '14:45',
#    'periodTimeRemaining': '05:15',
#    'dateTime': '2019-10-03T00:46:50Z',
#    'goals': {'away': 2, 'home': 3}},
#   'coordinates': {'x': 57.0, 'y': -22.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8479318,
#      'fullName': 'Auston Matthews',
#      'link': '/api/v1/people/8479318'},
#     'playerType': 'Scorer',
#     'seasonTotal': 2},
#    {'player': {'id': 8478483,
#      'fullName': 'Mitchell Marner',
#      'link': '/api/v1/people/8478483'},
#     'playerType': 'Assist',
#     'seasonTotal': 1},
#    {'player': {'id': 8475166,
#      'fullName': 'John Tavares',
#      'link': '/api/v1/people/8475166'},
#     'playerType': 'Assist',
#     'seasonTotal': 1},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Goal',
#    'eventCode': 'TOR610',
#    'eventTypeId': 'GOAL',
#    'description': 'Auston Matthews (2) Slap Shot, assists: Mitchell Marner (1), John Tavares (1)',
#    'secondaryType': 'Slap Shot',
#    'strength': {'code': 'PPG', 'name': 'Power Play'},
#    'gameWinningGoal': True,
#    'emptyNet': False},
#   'about': {'eventIdx': 232,
#    'eventId': 610,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '14:50',
#    'periodTimeRemaining': '05:10',
#    'dateTime': '2019-10-03T00:47:17Z',
#    'goals': {'away': 2, 'home': 4}},
#   'coordinates': {'x': 65.0, 'y': -20.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8479318,
#      'fullName': 'Auston Matthews',
#      'link': '/api/v1/people/8479318'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR614',
#    'eventTypeId': 'SHOT',
#    'description': 'Auston Matthews Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 247,
#    'eventId': 614,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '18:05',
#    'periodTimeRemaining': '01:55',
#    'dateTime': '2019-10-03T00:52:04Z',
#    'goals': {'away': 2, 'home': 4}},
#   'coordinates': {'x': 86.0, 'y': -9.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8479318,
#      'fullName': 'Auston Matthews',
#      'link': '/api/v1/people/8479318'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR615',
#    'eventTypeId': 'SHOT',
#    'description': 'Auston Matthews Snap Shot saved by Craig Anderson',
#    'secondaryType': 'Snap Shot'},
#   'about': {'eventIdx': 248,
#    'eventId': 615,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '18:18',
#    'periodTimeRemaining': '01:42',
#    'dateTime': '2019-10-03T00:52:16Z',
#    'goals': {'away': 2, 'home': 4}},
#   'coordinates': {'x': 60.0, 'y': -1.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8478483,
#      'fullName': 'Mitchell Marner',
#      'link': '/api/v1/people/8478483'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR617',
#    'eventTypeId': 'SHOT',
#    'description': 'Mitchell Marner Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 251,
#    'eventId': 617,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '18:53',
#    'periodTimeRemaining': '01:07',
#    'dateTime': '2019-10-03T00:52:51Z',
#    'goals': {'away': 2, 'home': 4}},
#   'coordinates': {'x': 45.0, 'y': -22.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8477953,
#      'fullName': 'Kasperi Kapanen',
#      'link': '/api/v1/people/8477953'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR618',
#    'eventTypeId': 'SHOT',
#    'description': 'Kasperi Kapanen Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 252,
#    'eventId': 618,
#    'period': 2,
#    'periodType': 'REGULAR',
#    'ordinalNum': '2nd',
#    'periodTime': '19:08',
#    'periodTimeRemaining': '00:52',
#    'dateTime': '2019-10-03T00:53:07Z',
#    'goals': {'away': 2, 'home': 4}},
#   'coordinates': {'x': 29.0, 'y': 21.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8474162,
#      'fullName': 'Jake Muzzin',
#      'link': '/api/v1/people/8474162'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR632',
#    'eventTypeId': 'SHOT',
#    'description': 'Jake Muzzin Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 269,
#    'eventId': 632,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '00:59',
#    'periodTimeRemaining': '19:01',
#    'dateTime': '2019-10-03T01:14:25Z',
#    'goals': {'away': 2, 'home': 4}},
#   'coordinates': {'x': -33.0, 'y': -25.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8477341,
#      'fullName': 'Andreas Johnsson',
#      'link': '/api/v1/people/8477341'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR635',
#    'eventTypeId': 'SHOT',
#    'description': 'Andreas Johnsson Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 274,
#    'eventId': 635,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '01:32',
#    'periodTimeRemaining': '18:28',
#    'dateTime': '2019-10-03T01:15:29Z',
#    'goals': {'away': 2, 'home': 4}},
#   'coordinates': {'x': -89.0, 'y': 25.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8479675,
#      'fullName': 'Trevor Moore',
#      'link': '/api/v1/people/8479675'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR636',
#    'eventTypeId': 'SHOT',
#    'description': 'Trevor Moore Snap Shot saved by Craig Anderson',
#    'secondaryType': 'Snap Shot'},
#   'about': {'eventIdx': 277,
#    'eventId': 636,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '02:00',
#    'periodTimeRemaining': '18:00',
#    'dateTime': '2019-10-03T01:15:55Z',
#    'goals': {'away': 2, 'home': 4}},
#   'coordinates': {'x': -56.0, 'y': -15.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8475197,
#      'fullName': 'Tyson Barrie',
#      'link': '/api/v1/people/8475197'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR638',
#    'eventTypeId': 'SHOT',
#    'description': 'Tyson Barrie Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 281,
#    'eventId': 638,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '02:15',
#    'periodTimeRemaining': '17:45',
#    'dateTime': '2019-10-03T01:16:35Z',
#    'goals': {'away': 2, 'home': 4}},
#   'coordinates': {'x': -68.0, 'y': -25.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8477341,
#      'fullName': 'Andreas Johnsson',
#      'link': '/api/v1/people/8477341'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR640',
#    'eventTypeId': 'SHOT',
#    'description': 'Andreas Johnsson Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 287,
#    'eventId': 640,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '03:42',
#    'periodTimeRemaining': '16:18',
#    'dateTime': '2019-10-03T01:18:56Z',
#    'goals': {'away': 2, 'home': 4}},
#   'coordinates': {'x': -67.0, 'y': 19.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8479318,
#      'fullName': 'Auston Matthews',
#      'link': '/api/v1/people/8479318'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR641',
#    'eventTypeId': 'SHOT',
#    'description': 'Auston Matthews Slap Shot saved by Craig Anderson',
#    'secondaryType': 'Slap Shot'},
#   'about': {'eventIdx': 288,
#    'eventId': 641,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '03:51',
#    'periodTimeRemaining': '16:09',
#    'dateTime': '2019-10-03T01:19:04Z',
#    'goals': {'away': 2, 'home': 4}},
#   'coordinates': {'x': -70.0, 'y': 23.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8474697,
#      'fullName': 'Mark Borowiecki',
#      'link': '/api/v1/people/8474697'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR646',
#    'eventTypeId': 'SHOT',
#    'description': 'Mark Borowiecki Wrist Shot saved by Frederik Andersen',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 294,
#    'eventId': 646,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '05:14',
#    'periodTimeRemaining': '14:46',
#    'dateTime': '2019-10-03T01:20:28Z',
#    'goals': {'away': 2, 'home': 4}},
#   'coordinates': {'x': -43.0, 'y': 0.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8473573,
#      'fullName': 'Artem Anisimov',
#      'link': '/api/v1/people/8473573'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR648',
#    'eventTypeId': 'SHOT',
#    'description': 'Artem Anisimov Wrist Shot saved by Frederik Andersen',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 300,
#    'eventId': 648,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '07:38',
#    'periodTimeRemaining': '12:22',
#    'dateTime': '2019-10-03T01:23:33Z',
#    'goals': {'away': 2, 'home': 4}},
#   'coordinates': {'x': 55.0, 'y': 28.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8479318,
#      'fullName': 'Auston Matthews',
#      'link': '/api/v1/people/8479318'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR802',
#    'eventTypeId': 'SHOT',
#    'description': 'Auston Matthews Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 308,
#    'eventId': 802,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '08:21',
#    'periodTimeRemaining': '11:39',
#    'dateTime': '2019-10-03T01:26:58Z',
#    'goals': {'away': 2, 'home': 4}},
#   'coordinates': {'x': -62.0, 'y': 11.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8481624,
#      'fullName': 'Ilya Mikheyev',
#      'link': '/api/v1/people/8481624'},
#     'playerType': 'Scorer',
#     'seasonTotal': 1},
#    {'player': {'id': 8475197,
#      'fullName': 'Tyson Barrie',
#      'link': '/api/v1/people/8475197'},
#     'playerType': 'Assist',
#     'seasonTotal': 2},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Goal',
#    'eventCode': 'TOR804',
#    'eventTypeId': 'GOAL',
#    'description': 'Ilya Mikheyev (1) Wrist Shot, assists: Tyson Barrie (2)',
#    'secondaryType': 'Wrist Shot',
#    'strength': {'code': 'EVEN', 'name': 'Even'},
#    'gameWinningGoal': False,
#    'emptyNet': False},
#   'about': {'eventIdx': 314,
#    'eventId': 804,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '09:43',
#    'periodTimeRemaining': '10:17',
#    'dateTime': '2019-10-03T01:28:46Z',
#    'goals': {'away': 2, 'home': 5}},
#   'coordinates': {'x': -78.0, 'y': 9.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8479458,
#      'fullName': 'Nikita Zaitsev',
#      'link': '/api/v1/people/8479458'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR807',
#    'eventTypeId': 'SHOT',
#    'description': 'Nikita Zaitsev Wrist Shot saved by Frederik Andersen',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 320,
#    'eventId': 807,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '10:32',
#    'periodTimeRemaining': '09:28',
#    'dateTime': '2019-10-03T01:30:36Z',
#    'goals': {'away': 2, 'home': 5}},
#   'coordinates': {'x': 70.0, 'y': -38.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8479675,
#      'fullName': 'Trevor Moore',
#      'link': '/api/v1/people/8479675'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR814',
#    'eventTypeId': 'SHOT',
#    'description': 'Trevor Moore Slap Shot saved by Craig Anderson',
#    'secondaryType': 'Slap Shot'},
#   'about': {'eventIdx': 338,
#    'eventId': 814,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '13:42',
#    'periodTimeRemaining': '06:18',
#    'dateTime': '2019-10-03T01:37:41Z',
#    'goals': {'away': 2, 'home': 5}},
#   'coordinates': {'x': -59.0, 'y': -21.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8477149,
#      'fullName': 'Scott Sabourin',
#      'link': '/api/v1/people/8477149'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR815',
#    'eventTypeId': 'SHOT',
#    'description': 'Scott Sabourin Backhand saved by Frederik Andersen',
#    'secondaryType': 'Backhand'},
#   'about': {'eventIdx': 339,
#    'eventId': 815,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '13:55',
#    'periodTimeRemaining': '06:05',
#    'dateTime': '2019-10-03T01:38:02Z',
#    'goals': {'away': 2, 'home': 5}},
#   'coordinates': {'x': 5.0, 'y': -17.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8478469,
#      'fullName': 'Thomas Chabot',
#      'link': '/api/v1/people/8478469'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR817',
#    'eventTypeId': 'SHOT',
#    'description': 'Thomas Chabot Slap Shot saved by Frederik Andersen',
#    'secondaryType': 'Slap Shot'},
#   'about': {'eventIdx': 342,
#    'eventId': 817,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '14:26',
#    'periodTimeRemaining': '05:34',
#    'dateTime': '2019-10-03T01:38:53Z',
#    'goals': {'away': 2, 'home': 5}},
#   'coordinates': {'x': 2.0, 'y': 31.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8475716,
#      'fullName': 'Martin Marincin',
#      'link': '/api/v1/people/8475716'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR818',
#    'eventTypeId': 'SHOT',
#    'description': 'Martin Marincin Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 345,
#    'eventId': 818,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '14:58',
#    'periodTimeRemaining': '05:02',
#    'dateTime': '2019-10-03T01:39:23Z',
#    'goals': {'away': 2, 'home': 5}},
#   'coordinates': {'x': 66.0, 'y': 41.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8477149,
#      'fullName': 'Scott Sabourin',
#      'link': '/api/v1/people/8477149'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR820',
#    'eventTypeId': 'SHOT',
#    'description': 'Scott Sabourin Slap Shot saved by Frederik Andersen',
#    'secondaryType': 'Slap Shot'},
#   'about': {'eventIdx': 350,
#    'eventId': 820,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '15:52',
#    'periodTimeRemaining': '04:08',
#    'dateTime': '2019-10-03T01:40:17Z',
#    'goals': {'away': 2, 'home': 5}},
#   'coordinates': {'x': 64.0, 'y': -10.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8478483,
#      'fullName': 'Mitchell Marner',
#      'link': '/api/v1/people/8478483'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8467950,
#      'fullName': 'Craig Anderson',
#      'link': '/api/v1/people/8467950'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR822',
#    'eventTypeId': 'SHOT',
#    'description': 'Mitchell Marner Wrist Shot saved by Craig Anderson',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 352,
#    'eventId': 822,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '16:26',
#    'periodTimeRemaining': '03:34',
#    'dateTime': '2019-10-03T01:40:52Z',
#    'goals': {'away': 2, 'home': 5}},
#   'coordinates': {'x': -62.0, 'y': -26.0},
#   'team': {'id': 10,
#    'name': 'Toronto Maple Leafs',
#    'link': '/api/v1/teams/10',
#    'triCode': 'TOR'}},
#  {'players': [{'player': {'id': 8476919,
#      'fullName': 'Chris Tierney',
#      'link': '/api/v1/people/8476919'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR828',
#    'eventTypeId': 'SHOT',
#    'description': 'Chris Tierney Wrist Shot saved by Frederik Andersen',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 361,
#    'eventId': 828,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '17:45',
#    'periodTimeRemaining': '02:15',
#    'dateTime': '2019-10-03T01:44:53Z',
#    'goals': {'away': 2, 'home': 5}},
#   'coordinates': {'x': 85.0, 'y': 30.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8471676,
#      'fullName': 'Bobby Ryan',
#      'link': '/api/v1/people/8471676'},
#     'playerType': 'Scorer',
#     'seasonTotal': 1},
#    {'player': {'id': 8476919,
#      'fullName': 'Chris Tierney',
#      'link': '/api/v1/people/8476919'},
#     'playerType': 'Assist',
#     'seasonTotal': 1},
#    {'player': {'id': 8474697,
#      'fullName': 'Mark Borowiecki',
#      'link': '/api/v1/people/8474697'},
#     'playerType': 'Assist',
#     'seasonTotal': 1},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Goal',
#    'eventCode': 'TOR829',
#    'eventTypeId': 'GOAL',
#    'description': 'Bobby Ryan (1) Wrist Shot, assists: Chris Tierney (1), Mark Borowiecki (1)',
#    'secondaryType': 'Wrist Shot',
#    'strength': {'code': 'EVEN', 'name': 'Even'},
#    'gameWinningGoal': False,
#    'emptyNet': False},
#   'about': {'eventIdx': 362,
#    'eventId': 829,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '17:45',
#    'periodTimeRemaining': '02:15',
#    'dateTime': '2019-10-03T01:44:59Z',
#    'goals': {'away': 3, 'home': 5}},
#   'coordinates': {'x': 72.0, 'y': 2.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8478469,
#      'fullName': 'Thomas Chabot',
#      'link': '/api/v1/people/8478469'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR833',
#    'eventTypeId': 'SHOT',
#    'description': 'Thomas Chabot Slap Shot saved by Frederik Andersen',
#    'secondaryType': 'Slap Shot'},
#   'about': {'eventIdx': 368,
#    'eventId': 833,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '18:22',
#    'periodTimeRemaining': '01:38',
#    'dateTime': '2019-10-03T01:47:27Z',
#    'goals': {'away': 3, 'home': 5}},
#   'coordinates': {'x': 38.0, 'y': -24.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8477407,
#      'fullName': 'Anthony Duclair',
#      'link': '/api/v1/people/8477407'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR834',
#    'eventTypeId': 'SHOT',
#    'description': 'Anthony Duclair Wrist Shot saved by Frederik Andersen',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 369,
#    'eventId': 834,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '18:44',
#    'periodTimeRemaining': '01:16',
#    'dateTime': '2019-10-03T01:47:49Z',
#    'goals': {'away': 3, 'home': 5}},
#   'coordinates': {'x': 64.0, 'y': 28.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}},
#  {'players': [{'player': {'id': 8478469,
#      'fullName': 'Thomas Chabot',
#      'link': '/api/v1/people/8478469'},
#     'playerType': 'Shooter'},
#    {'player': {'id': 8475883,
#      'fullName': 'Frederik Andersen',
#      'link': '/api/v1/people/8475883'},
#     'playerType': 'Goalie'}],
#   'result': {'event': 'Shot',
#    'eventCode': 'TOR838',
#    'eventTypeId': 'SHOT',
#    'description': 'Thomas Chabot Wrist Shot saved by Frederik Andersen',
#    'secondaryType': 'Wrist Shot'},
#   'about': {'eventIdx': 376,
#    'eventId': 838,
#    'period': 3,
#    'periodType': 'REGULAR',
#    'ordinalNum': '3rd',
#    'periodTime': '19:37',
#    'periodTimeRemaining': '00:23',
#    'dateTime': '2019-10-03T01:49:43Z',
#    'goals': {'away': 3, 'home': 5}},
#   'coordinates': {'x': 48.0, 'y': 28.0},
#   'team': {'id': 9,
#    'name': 'Ottawa Senators',
#    'link': '/api/v1/teams/9',
#    'triCode': 'OTT'}}]

# %%
df['team'][0]['name']
# Out:
# 'Ottawa Senators'

# %%
df['result'][0]['eventTypeId']
# Out:
# 'GOAL'

# %%
df['coordinates'][0]['x']
# Out:
# 85.0

# %%
for a in df['players'][1]:
    if a['playerType'] == 'Scorer' or 'Shooter':
        print(a['player']['fullName'])
    print(a)
# Out:
# Morgan Rielly
# {'player': {'id': 8476853, 'fullName': 'Morgan Rielly', 'link': '/api/v1/people/8476853'}, 'playerType': 'Shooter'}
# Craig Anderson
# {'player': {'id': 8467950, 'fullName': 'Craig Anderson', 'link': '/api/v1/people/8467950'}, 'playerType': 'Goalie'}

# %%
df['players'][0][1]['playerType']

# %%
df['players'][0][1]['playerType'] == 'Scorer' or 'Shooter'
